# %%
import pybedtools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from get_TFBS_pair import get_pair

# %% [markdown]
# #

# %%
data = pybedtools.BedTool("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Promotor_with_TFBS/All_GTEx_Prom_with_TFBS.bed")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pybedtools.BedTool("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Promotor_with_TFBS/All_GTEx_Prom_with_TFBS.bed")
#
# NameError: name 'pybedtools' is not defined

# %%
# Out:
#        chr              geneID TFBS_close TFBS_dist  closest_TSS_distance  \
# 0     chr5  ENSG00000006837.11      SMAD3      ATF2                  -4.0
# 1     chr1  ENSG00000008128.22       ATF2     SMAD3                  24.0
# 2     chr3  ENSG00000008952.16       ATF2     SMAD3                  -9.0
# 3    chr12  ENSG00000010626.14      SMAD3      ATF2                  -7.0
# 4    chr12  ENSG00000023734.10      SMAD3      ATF2                   4.0
# ..     ...                 ...        ...       ...                   ...
# 125   chr4   ENSG00000268471.6       ATF2     SMAD3                 132.0
# 126   chr2   ENSG00000272994.1      SMAD3      ATF2                 117.0
# 127   chr7   ENSG00000276213.1      SMAD3      ATF2                  89.0
# 128   chr7   ENSG00000279086.1      SMAD3      ATF2                  22.0
# 129   chrX   ENSG00000281849.3       ATF2     SMAD3                  -9.0
#
#      furthest_TSS_distance orientation_of_pair  distance_between_pair  \
# 0                     98.0             both-nT                   75.0
# 1                    123.0              both-T                   70.0
# 2                    202.0          convergent                  188.0
# 3                     16.0             both-nT                   -6.0
# 4                    134.0              both-T                  101.0
# ..                     ...                 ...                    ...
# 125                  146.0             both-nT                  -13.0
# 126                  141.0              both-T                   -5.0
# 127                  125.0              both-T                    9.0
# 128                   53.0              both-T                    2.0
# 129                   17.0           divergent                   -1.0
#
#      tfbs_count  tfbs_count_unique
# 0         116.0               82.0
# 1         157.0              103.0
# 2          78.0               59.0
# 3          40.0               33.0
# 4         114.0               80.0
# ..          ...                ...
# 125       148.0               94.0
# 126       111.0               76.0
# 127       135.0               77.0
# 128        78.0               65.0
# 129        50.0               39.0
#
# [130 rows x 10 columns]

# %% [markdown]
# ##### Visualisation TFBS pair
# - Order
# - Orientation
# - distance_between_pair

# %%
data = pybedtools.BedTool("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Promotor_with_TFBS/All_GTEx_Prom_with_TFBS.bed")
tfbs_lst = ["SMAD3", "ATF2"]
df_pair = get_pair(data, tfbs_lst)

# %%
df_pair

# %%
smad_close = atf_smad_order_orient[atf_smad_order_orient["TFBS_close"]=="SMAD3"]
atf_close = atf_smad_order_orient[atf_smad_order_orient["TFBS_close"]=="ATF2"]
