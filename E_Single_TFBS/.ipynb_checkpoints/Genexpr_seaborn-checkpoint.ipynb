# %%
#import pybedtools

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
#import seaborn.objects as so

from scipy.stats import pearsonr, spearmanr
import glob

# %%
def flatten_tissues_expand_df(tfbs_df):
    tfbs_part_repeat = tfbs_df.iloc[:,:9]
    tfbs_part_flatten = tfbs_df.iloc[:,9:]
    
    repeat_df =  pd.DataFrame(np.repeat(tfbs_part_repeat.values, tfbs_part_flatten.shape[1], axis=0))
    flatten_arr = tfbs_part_flatten.to_numpy().flatten()

    tissue_repeat = np.tile(np.array(tfbs_part_flatten.columns), len(tfbs_part_repeat))
    
    repeat_df.columns = tfbs_part_repeat.columns
    repeat_df["All_tissues"] = flatten_arr
    repeat_df["Tissue"] = tissue_repeat
    

    return repeat_df

# %%
#path = "/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/All_TFBS.csv"
path = r"H:\Uni - iCloud - Alte Semester\BA\All_TFBS.csv"
df_combined = pd.read_csv(path)

# %%
flat_df = flatten_tissues_expand_df(df_combined)

# %%
flat_df
# Out:
#            chr              geneID  ... All_tissues                        Tissue
# 0         chr1  ENSG00000163209.14  ...       0.691        Adipose - Subcutaneous
# 1         chr1  ENSG00000163209.14  ...       1.043  Adipose - Visceral (Omentum)
# 2         chr1  ENSG00000163209.14  ...       1.906                 Adrenal Gland
# 3         chr1  ENSG00000163209.14  ...       1.397                Artery - Aorta
# 4         chr1  ENSG00000163209.14  ...       1.385             Artery - Coronary
# ...        ...                 ...  ...         ...                           ...
# 37849459  chr7  ENSG00000128512.20  ...       2.226                        Testis
# 37849460  chr7  ENSG00000128512.20  ...       7.504                       Thyroid
# 37849461  chr7  ENSG00000128512.20  ...      11.100                        Uterus
# 37849462  chr7  ENSG00000128512.20  ...       6.597                        Vagina
# 37849463  chr7  ENSG00000128512.20  ...       1.472                   Whole Blood
#
# [37849464 rows x 11 columns]

# %%
#sns.set_theme(style="ticks")
fig, ax = plt.subplots()
#ax.set_xscale("log", base=2)

ssns.relplot(flat_df, x="close_tss", y="All_tissues", hue="Tissue")


ax.xaxis.grid(True)
ax.set(ylabel="")
ax.set_ylabel("Gene Expression")
#fig.savefig("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/Genexpression_All_TFBS.png")
plt.show()
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\julia\AppData\Local\Temp\ipykernel_5632\3917545870.py", line 2, in <module>
#     fig, ax = plt.subplots()
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib\pyplot.py", line 1430, in subplots
#     "to be a boolean. Did you intend to use "
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib\_api\deprecation.py", line 454, in wrapper
#     return func(*args, **kwargs)
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib\pyplot.py", line 771, in figure
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib\pyplot.py", line 347, in new_figure_manager
#     current_framework = cbook._get_running_interactive_framework()
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib_inline\backend_inline.py", line 27, in new_figure_manager
#     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib\_api\deprecation.py", line 454, in wrapper
#     return func(*args, **kwargs)
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib\figure.py", line 2406, in __init__
#     subplotpars=None,  # rc figure.subplot.*
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib\figure.py", line 213, in __init__
#     self.set(**kwargs)
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib\artist.py", line 117, in <lambda>
#     class Artist:
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib\artist.py", line 1227, in set
#     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
#   File "C:\Users\julia\anaconda3\envs\spyder\lib\site-packages\matplotlib\cbook\__init__.py", line 1789, in normalize_kwargs
#     for canonical, alias_list in alias_mapping.items()
#
# AttributeError: 'Figure' object has no attribute 'items'
