# %%
#import pybedtools

import numpy as np
import pandas as pd

#import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
#import seaborn.objects as so

from scipy.stats import pearsonr, spearmanr
import glob

# %% [markdown]
# # Data

# %%
# MAC

# path = "/Users/julianmeigen/Uni/Bachelor/DATA/All_TFBS_new.csv"
# path_ens = "/Users/julianmeigen/Uni/Bachelor/DATA/DataSet_TFs_ENSEMBLE_IDs.txt"
# path_gtex = "/Users/julianmeigen/Uni/Bachelor/DATA/GTEx_GenExpr_ucsc.csv"

# %%
# Windows

path = r"C:\Users\julia\MyPython\BA\All_TFBS_new.csv"
path_ens = r"C:\Users\julia\MyPython\BA\Data\DataSet_TFs_ENSEMBLE_IDs.txt"
path_gtex = r"C:\Users\julia\MyPython\BA\GTEx_GenExpr_ucsc.csv"

# %%
# Linux

# path = "/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/All_TFBS.csv"
# path_ens = "/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/DataSet_TFs_ENSEMBLE_IDs.txt"
# path_gtex = "/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/GTEx_GenExpr_ucsc.csv"

# %%
# Load Data
df_combined = pd.read_csv(path)

# %%
# Filter homotypic TFBS raus, so dass jedes Gen nur einmal vorkommt. Wir wollen später ja nur die all_tfbs:unique_count_und daher ist tf egal
geneID_filter = df_combined.groupby(["geneID"]).cumcount()
geneID_df = df_combined[geneID_filter == 0]

# %%
sns.histplot(geneID_df.all_tfbs_unique_count)
# Out:
# <Axes: xlabel='all_tfbs_unique_count', ylabel='Count'>

# %% [markdown]
# ## Jointplot Anzahl unique TFBS VS. mean Gene Expression

# %%
# New Dataframe where all 0 Expression values where replaced through NANs tot not interfere with the np.log2 transforamtion. And only the tfs and the expression values are saved.
df_expr_log = pd.DataFrame({"# TFBS": geneID_df.all_tfbs_unique_count}).join(np.log2(df_combined.iloc[:,9:].replace(0, np.NAN)))
df_expr_log
# Out:
#         # TFBS  Adipose - Subcutaneous  Adipose - Visceral (Omentum)  \
# 0           20               -0.533242                      0.060739
# 1           11                5.667892                      5.444270
# 2           55                2.902460                      2.794312
# 3           81                4.980025                      5.069960
# 4           20                2.388190                      2.836530
# ...        ...                     ...                           ...
# 694090       1               -6.506353                           NaN
# 694918       1                1.086104                     -4.921390
# 696966       1               -3.120294                     -5.442222
# 697958       1               -1.630394                     -1.077041
# 699899       1                0.215368                      0.191563
#
#         Adrenal Gland  Artery - Aorta  Artery - Coronary  Artery - Tibial  \
# ...

# %%
# Calculate mean for each count of TFBS
mean_per_TFBS_count = df_expr_log.groupby(["# TFBS"]).mean()
mean_per_TFBS_count
# Out:
#         Adipose - Subcutaneous  Adipose - Visceral (Omentum)  Adrenal Gland  \
# # TFBS
# 1                     0.454822                      0.385888       0.149266
# 2                     0.898844                      0.827828       0.261527
# 3                     1.035148                      0.958319       0.369196
# 4                     0.612805                      0.534053       0.019131
# 5                     1.035787                      1.005757       0.546614
# ...                        ...                           ...            ...
# 115                   4.025915                      3.920293       3.662205
# 116                   1.557778                      1.258217       1.113034
# 120                   4.906404                      4.764325       4.517133
# 122                   2.833700                      2.874994       2.661294
# 138                   3.602884                      3.303927       3.526069
#
# ...

# %%
# fig = plt.subplots(figsize=(20,15))
# sns.boxplot(mean_per_TFBS_count, x=mean_per_TFBS_count.index, y=mean_per_TFBS_count.values )

# %% [markdown]
# ### Jointplot

# %%
# get number of unique TFBS in Promotor region for each gene
count_tfbs = df_expr_log["# TFBS"]
count_tfbs
# Out:
# 0         20
# 1         11
# 2         55
# 3         81
# 4         20
#           ..
# 694090     1
# 694918     1
# 696966     1
# 697958     1
# 699899     1
# Name: # TFBS, Length: 17304, dtype: int64

# %%
mean_expr_per_gene = df_expr_log.iloc[:,1:].mean(axis=1)
mean_expr_per_gene
# Out:
# 0         0.515928
# 1         5.179759
# 2         2.668530
# 3         4.396549
# 4         2.748832
#             ...
# 694090   -4.945223
# 694918   -0.591844
# 696966   -3.046788
# 697958   -1.216257
# 699899    0.174018
# Length: 17304, dtype: float64

# %%
# Jointplot
sns.jointplot(x=count_tfbs, y=mean_expr_per_gene)

# %% [markdown]
# ### Boxplot

# %%
fig
sns.boxplot(x=count_tfbs, y=mean_expr_per_gene)
# Out:
# <Axes: xlabel='# TFBS', ylabel='None'>

# %% [markdown]
# ### Histogram

# %%
sns.histplot(df_expr_log["# TFBS"], kde=True)
# Out:
# <Axes: xlabel='# TFBS', ylabel='Count'>

# %% [markdown]
# ### Hist und Box

# %%
fig, ax1 = plt.subplots(figsize=(10,6))

sns.boxplot(x=count_tfbs, y=mean_expr_per_gene, ax=ax1)

ax2 = ax1.twinx()  # Erstellen einer zweiten y-Achse
sns.histplot(count_tfbs, ax=ax2, kde=True)  # oder sns.kdeplot(df['expressions'], ax=ax2)

plt.show()

# %%
len(sorted(count_tfbs.unique()))
count_tfbs
# Out:
# 0         20
# 1         11
# 2         55
# 3         81
# 4         20
#           ..
# 694090     1
# 694918     1
# 696966     1
# 697958     1
# 699899     1
# Name: # TFBS, Length: 17304, dtype: int64

# %%
nans = np.empty(141)
nans[:] = np.NAN
nans
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
mean_expr_per_gene_add_nans = pd.concat([mean_expr_per_gene, pd.Series(nans)], ignore_index=True)
count_tfbs_add_nans = pd.concat([count_tfbs, pd.Series(np.arange(0,141))], ignore_index=True)

# %%
g = sns.JointGrid(x=count_tfbs_add_nans, y=mean_expr_per_gene_add_nans, height=10, marginal_ticks=True)
g.plot(sns.boxplot, sns.histplot)
g.set_axis_labels("# TFBS in Promotor","$log_2$(Gene Expression)")
g.ax_joint.set_xticks(np.arange(0, 141, 10))
# g.savefig("images_BA/Number_TFBS_Genexpression.pdf")

# %% [markdown]
# # Linear Regression and Correlaation Unique TFBS vs GeneExpression

# %%
def transform_expr_to_log_zero_to_nan(df, expr_iloc_start=9, expr_iloc_end=None):
    if expr_iloc_end is None:
        expr_iloc_end = len(df.columns)
    expr = df.iloc[:,expr_iloc_start:expr_iloc_end]
    replace_zero = expr.replace(0, np.NAN)
    expr_log2 = np.log2(replace_zero)
    df_new = df.copy()
    df_new.iloc[:,expr_iloc_start:expr_iloc_end] = expr_log2
    return df_new

# %%
geneID_df_transform = transform_expr_to_log_zero_to_nan(geneID_df)

# %%
def flatten_tissues_expand_df(tfbs_df, tissue_iloc =9):
    tfbs_part_repeat = tfbs_df.iloc[:,:tissue_iloc]
    tfbs_part_flatten = tfbs_df.iloc[:,tissue_iloc:]
    
    repeat_df =  pd.DataFrame(np.repeat(tfbs_part_repeat.values, tfbs_part_flatten.shape[1], axis=0))
    repeat_df = repeat_df.convert_dtypes(convert_integer = True)
    
    
    flatten_arr = tfbs_part_flatten.to_numpy().flatten()

    tissue_repeat = np.tile(np.array(tfbs_part_flatten.columns), len(tfbs_part_repeat))
    
    repeat_df.columns = tfbs_part_repeat.columns
    repeat_df["GeneExpr"] = flatten_arr
    repeat_df["Tissue"] = tissue_repeat
    
    return repeat_df


def get_pearson(df, x="homotypic_count", tissue="GeneExpr"):
    tfs = df["tf"].unique()
    r_lst = []
    p_lst = []
    tf_lst = []
    for tf in tfs:
        df_tf = df[df["tf"] == tf]
        if len(df_tf) >= 2:
            r, p_value = pearsonr(df_tf[x], np.array(df_tf[tissue]))
            r_lst.append(r)
            p_lst.append(p_value)
            tf_lst.append(tf)
        else:
            print(f"{tf} has less then 2 entrys. No Correlation could be calculated")
    pearson_df = pd.DataFrame({"TFs":tf_lst, "Pearson_r":r_lst, "Pearson_p":p_lst})

    return pearson_df

# %% [markdown]
# ### REMOVE zeros in Expr. column and calculate pearson between 2 columns

# %%
def remove_nans_and_calulate_pearson(df, col1="all_tfbs_unique_count", Expr_col="GeneExpr"):
    # Remove NAN values in Expression column
    df_no_zeros = df.dropna()
    # Caluclate Pearson
    pearson = pearsonr(df_no_zeros[col1], df_no_zeros[Expr_col])
    return pearson

# %%
geneID_df_flat = flatten_tissues_expand_df(geneID_df_transform)
pearson_flat = remove_nans_and_calulate_pearson(geneID_df_flat, col1="all_tfbs_count")

# %%
pearson_flat
geneID_df_flat
# Out:
#           chr              geneID      tf  close_tss  dist_tss  \
# 0        chr1  ENSG00000163209.14  HMBOX1        159       169
# 1        chr1  ENSG00000163209.14  HMBOX1        159       169
# 2        chr1  ENSG00000163209.14  HMBOX1        159       169
# 3        chr1  ENSG00000163209.14  HMBOX1        159       169
# 4        chr1  ENSG00000163209.14  HMBOX1        159       169
# ...       ...                 ...     ...        ...       ...
# 934411  chr22  ENSG00000189269.12  STAT5B         55        70
# 934412  chr22  ENSG00000189269.12  STAT5B         55        70
# 934413  chr22  ENSG00000189269.12  STAT5B         55        70
# 934414  chr22  ENSG00000189269.12  STAT5B         55        70
# 934415  chr22  ENSG00000189269.12  STAT5B         55        70
#
#        strand_orientation  homotypic_count  all_tfbs_count  \
# 0                      nT                1              24
# 1                      nT                1              24
# ...

# %% [markdown]
# ## Linear Regression Plot

# %%
mean_prom_expr = geneID_df_flat.groupby(["geneID"])["all_tfbs_unique_count","GeneExpr"].mean()
mean_prom_expr_nona = mean_prom_expr[mean_prom_expr["GeneExpr"].notna()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 mean_prom_expr = geneID_df_flat.groupby(["geneID"])["all_tfbs_unique_count","GeneExpr"].mean()
#       2 mean_prom_expr_nona = mean_prom_expr[mean_prom_expr["GeneExpr"].notna()]
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1947, in DataFrameGroupBy.__getitem__(self, key)
#    1943 # per GH 23566
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
# -> 1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
#    1951 return super().__getitem__(key)
#
# ...

# %%
# np.array(sorted(mean_prom_expr_nona.all_tfbs_unique_count.unique()))
# np.arange(1,140,1)[~np.isin(np.arange(1,140,1), np.array(sorted(mean_prom_expr_nona.all_tfbs_unique_count.unique())))]

# %%
# df_mean_expr_per_prom = geneID_df_flat.groupby(["geneID", "all_tfbs_unique_count"]).mean().reset_index()
# df_mean_expr_per_prom_sort = geneID_df_flat.sort_values(by="all_tfbs_unique_count")
# df_mean_expr_per_prom_sort_nona = df_mean_expr_per_prom_sort[df_mean_expr_per_prom_sort.GeneExpr.notna()]
# df_mean_expr_per_prom_sort_nona.sort_values("geneID")

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.regplot(mean_prom_expr, x=mean_prom_expr["all_tfbs_unique_count"].astype("float"), y=mean_prom_expr["GeneExpr"].astype("float"),
           ci=99, marker=".", color=".3", line_kws=dict(color="r"))
ax.set_xlabel("# TFBS per Promotor")
ax.set_ylabel("$log_2$(Gene Expression)")
# plt.grid()

# plt.savefig("images/linear_regression_unique_count_GeneExpr.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 fig, ax = plt.subplots(figsize=(10,10))
# ----> 2 sns.regplot(mean_prom_expr, x=mean_prom_expr["all_tfbs_unique_count"].astype("float"), y=mean_prom_expr["GeneExpr"].astype("float"),
#       3            ci=99, marker=".", color=".3", line_kws=dict(color="r"))
#       4 ax.set_xlabel("# TFBS per Promotor")
#       5 ax.set_ylabel("$log_2$(Gene Expression)")
#
# NameError: name 'mean_prom_expr' is not defined

# %% [markdown]
# ## Pearson Correlation to plot

# %%
pearson = pearsonr(mean_prom_expr_nona["GeneExpr"], mean_prom_expr_nona["all_tfbs_unique_count"])
pearson

# %% [markdown]
# # Rest

# %% [markdown]
# ### Plot Genexpression as scatter

# %%
df_mean_expr_per_prom = geneID_df_flat_no_zeros.groupby(["geneID", "all_tfbs_unique_count"]).mean().reset_index()
df_mean_expr_per_prom_sort = df_mean_expr_per_prom.sort_values(by="all_tfbs_unique_count")
df_mean_expr_per_prom_sort

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.regplot(df_mean_expr_per_prom_sort, x="all_tfbs_unique_count", y=np.log2(df_mean_expr_per_prom_sort["GeneExpr"]),
           ci=99, marker=".", color=".3", line_kws=dict(color="r"))
ax.set_xlabel("# TFBS per Promotor")
ax.set_ylabel("Gene Expression")


# plt.savefig("images/linear_regression_unique_count_GeneExpr.png")

# %% [markdown]
# ## Correlation for all Tissues

# %%
def get_pearson_all_tissues_unique_count(df, x="all_tfbs_unique_count", y_loc_start=9, y_loc_end=None ):
    if y_loc_end is None:
        y_loc_end=len(df.columns)
    tissues = np.array(df.columns[y_loc_start:y_loc_end])
    expr = np.array(df.iloc[:,y_loc_start:y_loc_end])
    
    r_all = np.array([])
    p_all = np.array([])
    for tissue in range(len(tissues)):
        tissue_expr = expr[:,tissue]
        
        r_tissue, p_tissue = pearsonr(df[x], tissue_expr)
        r_all = np.append(r_all, r_tissue)
        p_all = np.append(p_all, p_tissue)
    df = pd.DataFrame({"Pearson_r":r_all, "p_value":p_all})
    df.index = tissues
    return df

# %%
def get_pearson_all_tissues_unique_count_log2_expr(df, x="all_tfbs_unique_count", y_loc_start=9, y_loc_end=None ):
    if y_loc_end is None:
        y_loc_end=len(df.columns)
    tissues = np.array(df.columns[y_loc_start:y_loc_end])
    expr = np.array(df.iloc[:,y_loc_start:y_loc_end])
    
    
    r_all = np.array([])
    p_all = np.array([])
    for tissue in range(len(tissues)):
        tissue_expr = expr[:,tissue]
        
        expr_iszero_mask = tissue_expr != 0
        x_reduced = df[x][expr_iszero_mask]
        tissue_expr_reduced = tissue_expr[expr_iszero_mask]
        
        r_tissue, p_tissue = pearsonr(np.log2(x_reduced), np.log2(tissue_expr_reduced))
        r_all = np.append(r_all, r_tissue)
        p_all = np.append(p_all, p_tissue)
    df = pd.DataFrame({"Pearson_r":r_all, "p_value":p_all})
    df.index = tissues
    return df

# %%
get_pearson_all_tissues_unique_count_log2_expr(geneID_df)
# Out:
#                                            Pearson_r        p_value
# Adipose - Subcutaneous                      0.341509   0.000000e+00
# Adipose - Visceral (Omentum)                0.337352   0.000000e+00
# Adrenal Gland                               0.367122   0.000000e+00
# Artery - Aorta                              0.335180   0.000000e+00
# Artery - Coronary                           0.341240   0.000000e+00
# Artery - Tibial                             0.337572   0.000000e+00
# Bladder                                     0.366989   0.000000e+00
# Brain - Amygdala                            0.302369   0.000000e+00
# Brain - Anterior cingulate cortex (BA24)    0.299326   0.000000e+00
# Brain - Caudate (basal ganglia)             0.311082   0.000000e+00
# Brain - Cerebellar Hemisphere               0.322046   0.000000e+00
# Brain - Cerebellum                          0.316957   0.000000e+00
# Brain - Cortex                              0.301865   0.000000e+00
# ...

# %%
geneID_df
# Out:
#           chr              geneID      tf  close_tss  dist_tss  \
# 0        chr1  ENSG00000163209.14  HMBOX1        159       169
# 1        chr1  ENSG00000143569.18  HMBOX1          9        19
# 2       chr10  ENSG00000213390.10  HMBOX1         47        57
# 3        chr1  ENSG00000169241.17  HMBOX1        160       170
# 4        chr1  ENSG00000185499.16  HMBOX1        173       183
# ...       ...                 ...     ...        ...       ...
# 694153   chr2  ENSG00000144481.16    KLF9         65        81
# 694981   chr2   ENSG00000198914.3    KLF9        148       164
# 697030  chr15   ENSG00000235711.4    BATF        121       132
# 698025  chr17   ENSG00000005381.7   PLAG1        121       135
# 699966  chr22  ENSG00000189269.12  STAT5B         55        70
#
#        strand_orientation  homotypic_count  all_tfbs_count  \
# 0                      nT                1              24
# 1                       T                1              12
# ...

# %% [markdown]
# ## Plot correlation

# %%
corr_unique_count = pd.read_table("corr_unique_tfbs.txt")

# %%
corr_unique_count
# Out:
#                               Pearson_r        p_value
# Adipose - Subcutaneous         0.341509   0.000000e+00
# Adipose - Visceral (Omentum)   0.337352   0.000000e+00
# Adrenal Gland                  0.367122   0.000000e+00
# Artery - Aorta                 0.335180   0.000000e+00
# Artery - Coronary              0.341240   0.000000e+00
# ...                                 ...            ...
# Testis                         0.353083   0.000000e+00
# Thyroid                        0.360200   0.000000e+00
# Uterus                         0.359484   0.000000e+00
# Vagina                         0.354377   0.000000e+00
# Whole Blood                    0.284737  6.675752e-282
#
# [108 rows x 2 columns]

# %%
# For flat_df_reduced
fig, ax = plt.subplots(figsize=(10,20))

norm = plt.Normalize(corr_unique_count["p_value"].min(), corr_unique_count["p_value"].max())
sm = plt.cm.ScalarMappable(cmap="rocket", norm=norm)

sns.barplot(x=corr_unique_count["Pearson_r"], y=corr_unique_count.index, hue=corr_unique_count["p_value"], width=0.5, palette="rocket")


ax.set_ylabel('Tissues')

ax.xaxis.tick_top()
ax.set_xlabel('Pearson Correlation of log2(GeneExpr)')
ax.xaxis.set_label_position("top")

ax.xaxis.grid(True)
ax.get_legend().remove()

plt.subplots_adjust(top=0.9)
cbar = ax.figure.colorbar(sm, ax=ax, orientation= "horizontal", location="top", )
cbar.set_label("p-value")

#fig.savefig("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/Boxplot/Pearson_corr_all_great_p.png")
