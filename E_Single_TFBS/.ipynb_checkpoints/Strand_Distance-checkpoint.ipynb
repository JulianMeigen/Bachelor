# %%
#import pybedtools

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt


import seaborn as sns
#import seaborn.objects as so

from scipy.stats import pearsonr, spearmanr
#import glob

# %% [markdown]
# # Data

# %% [markdown]
# # Read Data - NEW

# %%
#path = "/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/All_TFBS.csv"
# path = r"C:\Users\julia\MyPython\BA\All_TFBS.csv"
# df_combined = pd.read_csv(path)
# df_combined = df_combined[df_combined["chr"] != "chrM"]#df_red = reduce_homotypic_tfbs_occurence_consider_strand(df_combined)

# %%
# MAC

path = "/Users/julianmeigen/Uni/Bachelor/DATA/All_TFBS_new.csv"
# path_ens = "/Users/julianmeigen/Uni/Bachelor/DATA/DataSet_TFs_ENSEMBLE_IDs.txt"
# path_gtex = "/Users/julianmeigen/Uni/Bachelor/DATA/GTEx_GenExpr_ucsc.csv"

path_homotypic = "/Users/julianmeigen/Uni/Bachelor/DATA/Homotypic_All_TFBS_new.csv"

# %%
df_combined = pd.read_csv(path)

# %%
strand_count = np.unique(df_combined.strand_orientation, return_counts=True)
strand_count
# Out:
# (array(['T', 'nT'], dtype=object), array([347770, 353079]))

# %%
strand_count[1][1] / strand_count[1][0]
# Out:
# 1.0152658366161544

# %%
df_homotypic = pd.read_csv(path_homotypic)

# %%
np.unique(df_homotypic.strand_orientation, return_counts=True)
# Out:
# (array(['T', 'nT'], dtype=object), array([349672, 354939]))

# %%
def transform_df_expression_to_log2(df, columns_saved=["tf"], iloc_start=9, iloc_end=None, replace_zero=True):
    # Set iloc_end to last column
    if iloc_end is None:
        iloc_end = len(df.columns)
    # CHECK if zeros should replaced by NANs before transformed to prevent -inf values
    if replace_zero:
        # New Dataframe where all 0 Expression values where replaced through NANs tot not interfere with the np.log2 transforamtion. And only the tfs and the expression values are saved.
        df_expr_log = pd.DataFrame({col_name:df[col_name] for col_name in columns_saved}).join(np.log2(df.iloc[:,iloc_start:iloc_end].replace(0, np.NAN)))
    else:
        df_expr_log = pd.DataFrame({col_name:df[col_name] for col_name in columns_saved}).join(np.log2(df.iloc[:,iloc_start:iloc_end]))
    return df_expr_log

# %%
# Function to add a new column labeling the Stran-Orientation for the TFBSs

def add_strand_orientation_pct(df):
    """
    Calculates the fraction for TFBS occurences for each TFBS and adds a new column at the end of the DataFrame.
    1 = all non-Template Strand 
    -1 =  all Template strand
    """
    df_change = df.copy()
    df_change["strand_orientation"] = np.array([1 if i == "nT" else -1 for i in df["strand_orientation"]])
    mean_orientation_arr = df_change.groupby(by=["tf", "geneID", "homotypic_count"])["strand_orientation"].transform("mean")
    df_strand = df.copy()
    df_strand.insert(loc=6, column="homotypic_strand_orientation", value=mean_orientation_arr)
    return df_strand

# %%
df_combined_log = transform_df_expression_to_log2(df_combined, columns_saved=df_combined.columns[:9])

# %%
df_combined_log
# Out:
#           chr              geneID      tf  close_tss  dist_tss  \
# 0        chr1  ENSG00000163209.14  HMBOX1        159       169
# 1        chr1  ENSG00000143569.18  HMBOX1          9        19
# 2       chr10  ENSG00000213390.10  HMBOX1         47        57
# 3        chr1  ENSG00000169241.17  HMBOX1        160       170
# 4        chr1  ENSG00000185499.16  HMBOX1        173       183
# ...       ...                 ...     ...        ...       ...
# 700844   chr7  ENSG00000105851.10  STAT5B         -3         8
# 700845   chr7  ENSG00000075790.10  STAT5B        124       135
# 700846   chr7   ENSG00000128590.4  STAT5B         54        69
# 700847   chr7   ENSG00000198839.9  STAT5B         56        71
# 700848   chr7  ENSG00000128512.20  STAT5B        105       120
#
#        strand_orientation  homotypic_count  all_tfbs_count  \
# 0                      nT                1              24
# 1                       T                1              12
# ...

# %%
df_log_strand = add_strand_orientation_pct(df_combined_log)

# %%
def reduce_homotypic_tfbs_occurence_consider_strand(df):
    occur_region = df.groupby(["chr", "geneID", "tf", "homotypic_count"]).cumcount()
    df_red = df[occur_region == 0]
    return df_red

# %%
df_log_strand_red = reduce_homotypic_tfbs_occurence_consider_strand(df_log_strand)

# %%
df_log_strand_red
# Out:
#           chr              geneID      tf  close_tss  dist_tss  \
# 0        chr1  ENSG00000163209.14  HMBOX1        159       169
# 1        chr1  ENSG00000143569.18  HMBOX1          9        19
# 2       chr10  ENSG00000213390.10  HMBOX1         47        57
# 3        chr1  ENSG00000169241.17  HMBOX1        160       170
# 4        chr1  ENSG00000185499.16  HMBOX1        173       183
# ...       ...                 ...     ...        ...       ...
# 700844   chr7  ENSG00000105851.10  STAT5B         -3         8
# 700845   chr7  ENSG00000075790.10  STAT5B        124       135
# 700846   chr7   ENSG00000128590.4  STAT5B         54        69
# 700847   chr7   ENSG00000198839.9  STAT5B         56        71
# 700848   chr7  ENSG00000128512.20  STAT5B        105       120
#
#        strand_orientation  homotypic_strand_orientation  homotypic_count  \
# 0                      nT                           1.0                1
# ...

# %% [markdown]
# ## Filter for all nT (1) and all T (-1)

# %%
df_all_nT =  df_log_strand_red[df_log_strand_red["homotypic_strand_orientation"] == 1]
df_all_T =  df_log_strand_red[df_log_strand_red["homotypic_strand_orientation"] == -1]

# %%
df_nT = pd.DataFrame({"tf": df_all_nT.tf}).join(df_all_nT.iloc[:,10:])
df_T = pd.DataFrame({"tf": df_all_T.tf}).join(df_all_T.iloc[:,10:])

# %%
mean_per_tf_nT = df_nT.groupby(["tf"]).mean()
mean_per_tf_T = df_T.groupby(["tf"]).mean()

# %%
mean_per_tf_nT
# Out:
#         Adipose - Subcutaneous  Adipose - Visceral (Omentum)  Adrenal Gland  \
# tf
# AR                    3.131775                      3.060407       2.832939
# ARNT                  3.345547                      3.211043       3.085830
# ARNTL                 3.953439                      3.888917       3.555047
# ASCL1                 2.786115                      2.636469       2.426065
# ATF2                  3.182557                      3.094492       2.912812
# ...                        ...                           ...            ...
# YY2                   4.070098                      3.912819       3.762763
# ZFX                   3.947341                      3.790839       3.575173
# ZNF143                3.486211                      3.363745       3.221958
# ZNF263                3.035211                      2.902972       2.617064
# ZNF740                3.656782                      3.572374       3.329423
#
# ...

# %% [markdown]
# ### Count_ID

# %%
tf_id_count_nT = df_all_nT.groupby(["tf"])["geneID"].nunique()
tf_id_count_T = df_all_T.groupby(["tf"])["geneID"].nunique()

# %% [markdown]
# ### Mean Col and Row

# %%
gene_unique_nT = df_all_nT[df_all_nT.groupby(["geneID"]).cumcount()==0]
gene_unique_T = df_all_T[df_all_T.groupby(["geneID"]).cumcount()==0]

# %%
# Calculate Mean for all Genes included in the sub-dataset
col_means_nT = gene_unique_nT.iloc[:,10:].mean()
col_means_T = gene_unique_T.iloc[:,10:].mean()

# %%
## Tabelle für Supp Files:
# Runden ?? 

# print(col_means.to_latex())
# col_means.sort_values()

# %%
# ADD ROW all genes AND COLUMN mean row to nT
mean_per_tf_nT_copy = mean_per_tf_nT.copy()
mean_per_tf_nT_copy = pd.concat([col_means_nT.to_frame(name="All Genes").T, mean_per_tf_nT_copy])
mean_per_tf_nT_copy["Row Mean"] = mean_per_tf_nT_copy.mean(axis=1)

# ADD ROW all genes AND COLUMN mean row to T
mean_per_tf_T_copy = mean_per_tf_T.copy()
mean_per_tf_T_copy = pd.concat([col_means_T.to_frame(name="All Genes").T, mean_per_tf_T_copy])
mean_per_tf_T_copy["Row Mean"] = mean_per_tf_T_copy.mean(axis=1)

# %% [markdown]
# ### mean DIFF

# %%
mean_nT_diff_T = (mean_per_tf_nT_copy.mean(axis=1) - mean_per_tf_T_copy.mean(axis=1)).sort_values(ascending=False).head(15)

# %%
mean_T_diff_nT = (mean_per_tf_T_copy.mean(axis=1) - mean_per_tf_nT_copy.mean(axis=1)).sort_values(ascending=False).head(15)

# %%
#df = mean_nt_diff_T.sort_values(ascending=False).head(15).to_frame(name="nT").reset_index()

# %%
#df["TFs"] = mean_T_diff_nT.sort_values(ascending=False).head(15).index
#df["T"] = mean_T_diff_nT.sort_values(ascending=False).head(15).values

# %%
print(mean_nT_diff_T.to_latex(formatters=["{:,.3f}".format]))
# Out:
# \begin{tabular}{lr}
# \toprule
# {} &     0 \\
# \midrule
# POU2F1  & 1.970 \\
# HSF2    & 1.735 \\
# ISL1    & 1.482 \\
# E2F8    & 1.402 \\
# MYOG    & 0.981 \\
# HNF1B   & 0.803 \\
# RFX2    & 0.801 \\
# ONECUT2 & 0.695 \\
# STAT6   & 0.694 \\
# CUX1    & 0.637 \\
# ELF5    & 0.578 \\
# STAT5A  & 0.426 \\
# FOSL1   & 0.406 \\
# LHX9    & 0.401 \\
# ARNTL   & 0.398 \\
# \bottomrule
# \end{tabular}
# /var/folders/b8/1yb15sfd7zv0nrfx35ff_mn40000gn/T/ipykernel_63894/2719029573.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(mean_nT_diff_T.to_latex(formatters=["{:,.3f}".format]))

# %%
print(mean_T_diff_nT.to_latex(formatters=["{:,.3f}".format]))
# Out:
# \begin{tabular}{lr}
# \toprule
# {} &     0 \\
# \midrule
# SOX10  & 2.940 \\
# HINFP  & 1.964 \\
# DUX4   & 1.022 \\
# MEF2C  & 0.987 \\
# PHOX2B & 0.899 \\
# LHX2   & 0.850 \\
# PBX1   & 0.785 \\
# HLF    & 0.744 \\
# NKX3-1 & 0.686 \\
# PRDM4  & 0.593 \\
# NR5A2  & 0.547 \\
# CEBPG  & 0.504 \\
# FOXK1  & 0.464 \\
# GFI1   & 0.425 \\
# GFI1B  & 0.424 \\
# \bottomrule
# \end{tabular}
# /var/folders/b8/1yb15sfd7zv0nrfx35ff_mn40000gn/T/ipykernel_63894/4191533704.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(mean_T_diff_nT.to_latex(formatters=["{:,.3f}".format]))

# %%
mean_T_diff_nT.sort_values(ascending=False).head(15)
# Out:
# SOX10     2.939924
# HINFP     1.964308
# DUX4      1.022334
# MEF2C     0.987363
# PHOX2B    0.899239
# LHX2      0.850277
# PBX1      0.784930
# HLF       0.744129
# NKX3-1    0.685704
# PRDM4     0.592503
# NR5A2     0.547448
# CEBPG     0.504186
# FOXK1     0.464100
# GFI1      0.424854
# GFI1B     0.424399
# dtype: float64

# %% [markdown]
# ### ALL PLOT

# %%
df_plot = mean_per_tf_T_copy
tf_id_count = tf_id_count_T
all_target_count = len(gene_unique_T)

# %%
value_min = 1.4
value_max = 4.3

my_cmap = plt.get_cmap("viridis").copy()
my_cmap.set_over("#FFFF99")
my_cmap.set_under("#000033")
norm = mpl.colors.Normalize(vmin= value_min, vmax= value_max)

asp = df_plot.shape[0]/float(df_plot.shape[1])
figw = 10
figh = figw*asp


gridspec_kw = {"height_ratios":[1,266], "width_ratios" : [54,1]}
heatmapkws = dict(square=False, cbar=False,  cmap=my_cmap, fmt=".2f", linewidths=0.01, vmin= value_min, vmax= value_max, robust=True)


fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(figw, figh), gridspec_kw=gridspec_kw)

# left = 0.07; right=0.87
# bottom = 0.1; top = 0.9

plt.subplots_adjust( wspace=0.06, hspace=0.01)



# sns.heatmap(mean_log2_expr_per_tissue_copy, cmap=my_cmap, fmt=".2f", linewidths=0.01, cbar_kws={"orientation": "horizontal", "location":"top", "label":"$log_2$(Gene Expression)", "extend":"both"}, vmin= value_min, vmax= value_max, robust=True)
# Mean over all tissues - row
sns.heatmap(df_plot.iloc[:1,:54], ax=axes[0,0], xticklabels=True, yticklabels=True,  **heatmapkws)

# Mean over all Target genes - column
sns.heatmap(df_plot.iloc[1:,54:], ax=axes[1,1], xticklabels=True, yticklabels=True,  **heatmapkws)
# Normal heatmap
sns.heatmap(df_plot.iloc[1:,:54], ax=axes[1,0], xticklabels=True, yticklabels=True,  **heatmapkws)
# mean gene expr over al
sns.heatmap(df_plot.iloc[:1,54:], ax=axes[0,1], xticklabels=True, yticklabels=True,  **heatmapkws)


# axes[0,0].set_xlabel('Tissues')
axes[1,0].set_ylabel('TFs')

# oben mean tissues, x-ticks rotieren und nach oben, unten weg, y-ticks auf keine rotation
axes[0,0].tick_params(axis="x",top=True,labeltop=True, labelbottom=False, bottom=False, labelrotation=90)
axes[0,0].tick_params(axis="y", labelrotation=0)

# kleines rechteck oben rechts, x ticks drehen und nach oben, unten entfernen, y1-ticks entfernen, y2-ticks auf rechte seite durch len(df_red) also anzahl Target gene insgesamt
axes[0,1].tick_params(axis="x",top=True,labeltop=True, labelbottom=False, bottom=False, labelrotation=90)
axes[0,1].tick_params(axis="y", labelrotation=90)
axes[0,1].set_ylim([0,axes[0,1].get_ylim()[0]])
axes[0,1].set_yticks(axes[0,1].get_yticks())
axes[0,1].set_yticklabels([all_target_count]) ## ALL Target Gene Count
axes[0,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)

# Main Heatmap, x ticks entfernen, y-ticks lassen
axes[1,0].set_xticklabels([])
axes[1,0].set_xticks([])

# rechte lange Spalte
# Hinzufügern der y2-beschriftung mit tf_id_count, entfernen der y1-ticks etc, entfernen der x-ticks
axes[1,1].set_yticks(axes[1,1].get_yticks())
axes[1,1].set_yticklabels(tf_id_count.values)
axes[1,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)
axes[1,1].set_xticklabels([])
axes[1,1].set_xticks([])



# Colorbar
# cax = fig.add_axes([0.12, 0.9, 0.8, 0.01])
cax = fig.add_axes([0.12,0.945,0.8,0.01])
sm = mpl.cm.ScalarMappable(cmap=my_cmap, norm=norm)
sm.set_array([])
fig.colorbar(sm, cax=cax, extend='both', orientation="horizontal", location="top", label="$log_2$(Gene Expression)")

# plt.tight_layout()
#plt.savefig("images_BA/target_gene_heatmap.png", bbox_inches = 'tight')

# %% [markdown]
# ## PART -TF

# %% [markdown]
# #### Reduce DataFrame

# %%
mean_row = ["All Genes"]

tf_most_target_genes = ['MYC', 'ESR1', 'SP1', 'CTCF', 'E2F1', 'MAX', 'RUNX1', 'TFAP2C', 'AR', 'KLF5', 'JUN', 'RELA', 'MYCN', 'CREB1', 'E2F6', 'SP2']

tf_smallest_expr = ["NR1H4", "SOX10", "HNF1B", "HNF1A", "ISL1"]
tf_biggest_expr = ["NR5A1", "XBP1", "TFEB", "HSF2", "NR2C1"]

# %% [markdown]
# #### Combined PLots

# %%
# For nT
df_nT = mean_per_tf_nT_copy
id_count_nT = tf_id_count_nT
all_target_count_nT = len(gene_unique_nT)

# %%
# For T - instance

nan_array = np.empty(len(mean_per_tf_T_copy.columns))
nan_array[:] = np.NAN
nan_array

df_T = mean_per_tf_T_copy
df_T.loc['NR5A1'] = nan_array

id_count_T = tf_id_count_T
id_count_T["NR5A1"] = 0

all_target_count_T = len(gene_unique_T)

# %%
## plot nT or T
df = df_T
id_count = id_count_T
all_target_count_nT = all_target_count_T

# %%
extreme_df_plot = df.loc[ mean_row + tf_biggest_expr+tf_smallest_expr]
extreme_id_count_plot = id_count.loc[tf_biggest_expr+tf_smallest_expr]

# %%
extreme_df_plot.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 extreme_df_plot.shape
#
# NameError: name 'extreme_df_plot' is not defined

# %%
most_df_plot = df.loc[mean_row + tf_most_target_genes]
most_id_count_plot = id_count.loc[tf_most_target_genes]

# %%
extreme_df_plot.min().min()
extreme_df_plot.max().max()
# Out:
# 5.092431862187429

# %%
value_min = 1.4
value_max = 4.3

my_cmap = plt.get_cmap("viridis").copy()
my_cmap.set_over("#FFFF99")
my_cmap.set_under("#000033")
norm = mpl.colors.Normalize(vmin= value_min, vmax= value_max)

asp = (extreme_df_plot.shape[0] + most_df_plot.shape[0]) /float(extreme_df_plot.shape[1])
figw = 13
figh = figw*asp


gridspec_kw = {"height_ratios":[1,len(extreme_df_plot), len(most_df_plot)], "width_ratios" : [54,1]}
heatmapkws = dict(square=False, cbar=False,  cmap=my_cmap, fmt=".2f", linewidths=0.01, vmin= value_min, vmax= value_max, robust=True)


fig, axes = plt.subplots(ncols=2, nrows=3, figsize=(figw, figh), gridspec_kw=gridspec_kw)

# left = 0.07; right=0.87
# bottom = 0.1; top = 0.9

plt.subplots_adjust(wspace=0.06, hspace=0.2)



# sns.heatmap(mean_log2_expr_per_tissue_copy, cmap=my_cmap, fmt=".2f", linewidths=0.01, cbar_kws={"orientation": "horizontal", "location":"top", "label":"$log_2$(Gene Expression)", "extend":"both"}, vmin= value_min, vmax= value_max, robust=True)
# Mean over all tissues - row
sns.heatmap(extreme_df_plot.iloc[:1,:54], ax=axes[0,0], xticklabels=True, yticklabels=True,  **heatmapkws)

# Mean over all Target genes - column
sns.heatmap(extreme_df_plot.iloc[1:,54:], ax=axes[1,1], xticklabels=True, yticklabels=True,  **heatmapkws)
# Normal heatmap
sns.heatmap(extreme_df_plot.iloc[1:,:54], ax=axes[1,0], xticklabels=True, yticklabels=True,  **heatmapkws)
# mean gene expr over all
sns.heatmap(extreme_df_plot.iloc[:1,54:], ax=axes[0,1], xticklabels=True, yticklabels=True,  **heatmapkws)


# PLOT 2

# Mean over all Target genes - column
sns.heatmap(most_df_plot.iloc[1:,54:], ax=axes[2,1], xticklabels=True, yticklabels=True,  **heatmapkws)
# Normal heatmap
sns.heatmap(most_df_plot.iloc[1:,:54], ax=axes[2,0], xticklabels=True, yticklabels=True,  **heatmapkws)



# axes[0,0].set_xlabel('Tissues')
axes[1,0].set_ylabel('$(a)$', rotation=0, labelpad = 20)

# oben mean tissues, x-ticks rotieren und nach oben, unten weg, y-ticks auf keine rotation
axes[0,0].tick_params(axis="x",top=True,labeltop=True, labelbottom=False, bottom=False, labelrotation=90)
axes[0,0].tick_params(axis="y", labelrotation=0)

# kleines rechteck oben rechts, x ticks drehen und nach oben, unten entfernen, y1-ticks entfernen, y2-ticks auf rechte seite durch len(df_red) also anzahl Target gene insgesamt
axes[0,1].tick_params(axis="x",top=True,labeltop=True, labelbottom=False, bottom=False, labelrotation=90)
axes[0,1].tick_params(axis="y", labelrotation=90)
axes[0,1].set_ylim([0,axes[0,1].get_ylim()[0]])
axes[0,1].set_yticks(axes[0,1].get_yticks())
axes[0,1].set_yticklabels([all_target_count])
axes[0,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)

# Main Heatmap, x ticks entfernen, y-ticks lassen
axes[1,0].set_xticklabels([])
axes[1,0].set_xticks([])

# rechte lange Spalte
# Hinzufügern der y2-beschriftung mit tf_id_count, entfernen der y1-ticks etc, entfernen der x-ticks
axes[1,1].set_yticks(axes[1,1].get_yticks())
axes[1,1].set_yticklabels(extreme_id_count_plot.values)
axes[1,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)
axes[1,1].set_xticklabels([])
axes[1,1].set_xticks([])


# PLOT 2 AXES

axes[2,0].set_ylabel('$(b)$', rotation=0, labelpad = 20)
# Main Heatmap, x ticks entfernen, y-ticks lassen
axes[2,0].set_xticklabels([])
axes[2,0].set_xticks([])

# rechte lange Spalte
# Hinzufügern der y2-beschriftung mit tf_id_count, entfernen der y1-ticks etc, entfernen der x-ticks
axes[2,1].set_yticks(axes[2,1].get_yticks())
axes[2,1].set_yticklabels(most_id_count_plot.values)
axes[2,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)
axes[2,1].set_xticklabels([])
axes[2,1].set_xticks([])


# Colorbar
# cax = fig.add_axes([0.12, 0.9, 0.8, 0.01])
cax = fig.add_axes([0.12,-.05,0.75,0.08])
sm = mpl.cm.ScalarMappable(cmap=my_cmap, norm=norm)
sm.set_array([])
fig.colorbar(sm, cax=cax, extend='both', orientation="horizontal", location="bottom", label="$log_2$(Gene Expression)")
# plt.tight_layout()
# plt.savefig(r"images_BA/T_heatmap_extreme_and_most.pdf", bbox_inches = 'tight')

# %% [markdown]
# ### nT - T Diff

# %%
df_nT_T = df_nT - df_T
#df_nT_T.loc["NR5A1"] = df_nT.loc["NR5A1"]

# %%
## GET all Target genes count
df_all_nT_T =  df_log_strand_red[(df_log_strand_red["homotypic_strand_orientation"] == 1) | (df_log_strand_red["homotypic_strand_orientation"] == -1)]

gene_unique_nT_T = df_all_nT_T[df_all_nT_T.groupby(["geneID"]).cumcount()==0]

# Analog zu id_count_nT + id_count_T
tf_id_count_nT_T = df_all_nT_T.groupby(["tf"])["geneID"].nunique()

# %%
## plot nT - T
df = df_nT_T
id_count = tf_id_count_nT_T
all_target_count_nT = len(gene_unique_nT_T)

# %%
extreme_df_plot = df.loc[ mean_row + tf_biggest_expr+tf_smallest_expr]
extreme_id_count_plot = id_count.loc[tf_biggest_expr+tf_smallest_expr]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 extreme_df_plot = df.loc[ mean_row + tf_biggest_expr+tf_smallest_expr]
#       2 extreme_id_count_plot = id_count.loc[tf_biggest_expr+tf_smallest_expr]
#
# NameError: name 'mean_row' is not defined

# %%
extreme_df_plot.shape
# Out:
# (11, 55)

# %%
most_df_plot = df.loc[mean_row + tf_most_target_genes]
most_id_count_plot = id_count.loc[tf_most_target_genes]

# %%
extreme_df_plot.min().min()
extreme_df_plot.max().max()
# Out:
# 5.7366048753142485

# %%
extreme_df_plot
# Out:
#            Adipose - Subcutaneous  Adipose - Visceral (Omentum)  \
# All Genes               -0.001510                     -0.012116
# NR5A1                    4.866908                      4.778209
# XBP1                     0.134440                      0.147197
# TFEB                    -0.601251                     -0.637236
# HSF2                     1.587603                      1.441803
# NR2C1                    0.182187                      0.212717
# NR1H4                   -0.534824                     -0.279239
# SOX10                   -4.457182                     -4.845146
# HNF1B                    1.273800                      0.936068
# HNF1A                   -0.174352                      0.246549
# ISL1                     1.129540                      0.973711
#
#            Adrenal Gland  Artery - Aorta  Artery - Coronary  Artery - Tibial  \
# All Genes       0.011572       -0.016462          -0.009016        -0.011502
# ...

# %%
value_min = -1
value_max = 1

my_cmap = plt.get_cmap("viridis").copy()
my_cmap.set_over("#FFFF99")
my_cmap.set_under("#000033")
norm = mpl.colors.Normalize(vmin= value_min, vmax= value_max)

asp = (extreme_df_plot.shape[0] + most_df_plot.shape[0]) /float(extreme_df_plot.shape[1])
figw = 13
figh = figw*asp


gridspec_kw = {"height_ratios":[1,len(extreme_df_plot), len(most_df_plot)], "width_ratios" : [54,1]}
heatmapkws = dict(square=False, cbar=False,  cmap=my_cmap, fmt=".2f", linewidths=0.01, vmin= value_min, vmax= value_max, robust=True)


fig, axes = plt.subplots(ncols=2, nrows=3, figsize=(figw, figh), gridspec_kw=gridspec_kw)

# left = 0.07; right=0.87
# bottom = 0.1; top = 0.9

plt.subplots_adjust(wspace=0.06, hspace=0.2)



# sns.heatmap(mean_log2_expr_per_tissue_copy, cmap=my_cmap, fmt=".2f", linewidths=0.01, cbar_kws={"orientation": "horizontal", "location":"top", "label":"$log_2$(Gene Expression)", "extend":"both"}, vmin= value_min, vmax= value_max, robust=True)
# Mean over all tissues - row
sns.heatmap(extreme_df_plot.iloc[:1,:54], ax=axes[0,0], xticklabels=True, yticklabels=True,  **heatmapkws)

# Mean over all Target genes - column
sns.heatmap(extreme_df_plot.iloc[1:,54:], ax=axes[1,1], xticklabels=True, yticklabels=True,  **heatmapkws)
# Normal heatmap
sns.heatmap(extreme_df_plot.iloc[1:,:54], ax=axes[1,0], xticklabels=True, yticklabels=True,  **heatmapkws)
# mean gene expr over all
sns.heatmap(extreme_df_plot.iloc[:1,54:], ax=axes[0,1], xticklabels=True, yticklabels=True,  **heatmapkws)


# PLOT 2

# Mean over all Target genes - column
sns.heatmap(most_df_plot.iloc[1:,54:], ax=axes[2,1], xticklabels=True, yticklabels=True,  **heatmapkws)
# Normal heatmap
sns.heatmap(most_df_plot.iloc[1:,:54], ax=axes[2,0], xticklabels=True, yticklabels=True,  **heatmapkws)



# axes[0,0].set_xlabel('Tissues')
axes[1,0].set_ylabel('$(a)$', rotation=0, labelpad = 20)

# oben mean tissues, x-ticks rotieren und nach oben, unten weg, y-ticks auf keine rotation
axes[0,0].tick_params(axis="x",top=True,labeltop=True, labelbottom=False, bottom=False, labelrotation=90)
axes[0,0].tick_params(axis="y", labelrotation=0)

# kleines rechteck oben rechts, x ticks drehen und nach oben, unten entfernen, y1-ticks entfernen, y2-ticks auf rechte seite durch len(df_red) also anzahl Target gene insgesamt
axes[0,1].tick_params(axis="x",top=True,labeltop=True, labelbottom=False, bottom=False, labelrotation=90)
axes[0,1].tick_params(axis="y", labelrotation=90)
axes[0,1].set_ylim([0,axes[0,1].get_ylim()[0]])
axes[0,1].set_yticks(axes[0,1].get_yticks())
axes[0,1].set_yticklabels([all_target_count])
axes[0,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)

# Main Heatmap, x ticks entfernen, y-ticks lassen
axes[1,0].set_xticklabels([])
axes[1,0].set_xticks([])

# rechte lange Spalte
# Hinzufügern der y2-beschriftung mit tf_id_count, entfernen der y1-ticks etc, entfernen der x-ticks
axes[1,1].set_yticks(axes[1,1].get_yticks())
axes[1,1].set_yticklabels(extreme_id_count_plot.values)
axes[1,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)
axes[1,1].set_xticklabels([])
axes[1,1].set_xticks([])


# PLOT 2 AXES

axes[2,0].set_ylabel('$(b)$', rotation=0, labelpad = 20)
# Main Heatmap, x ticks entfernen, y-ticks lassen
axes[2,0].set_xticklabels([])
axes[2,0].set_xticks([])

# rechte lange Spalte
# Hinzufügern der y2-beschriftung mit tf_id_count, entfernen der y1-ticks etc, entfernen der x-ticks
axes[2,1].set_yticks(axes[2,1].get_yticks())
axes[2,1].set_yticklabels(most_id_count_plot.values)
axes[2,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)
axes[2,1].set_xticklabels([])
axes[2,1].set_xticks([])


# Colorbar
# cax = fig.add_axes([0.12, 0.9, 0.8, 0.01])
cax = fig.add_axes([0.12,-.05,0.75,0.08])
sm = mpl.cm.ScalarMappable(cmap=my_cmap, norm=norm)
sm.set_array([])
fig.colorbar(sm, cax=cax, extend='both', orientation="horizontal", location="bottom", label="$log_2$(Gene Expression)")
# plt.tight_layout()
# plt.savefig(r"images_BA/T_heatmap_extreme_and_most.pdf", bbox_inches = 'tight')

# %% [markdown]
# ### extreme together and mean together

# %%
# For nT
df_nT = mean_per_tf_nT_copy
id_count_nT = tf_id_count_nT
all_target_count_nT = len(gene_unique_nT)



extreme_df_plot_nT = df_nT.loc[ mean_row + tf_biggest_expr+tf_smallest_expr]
extreme_id_count_plot_nT = id_count_nT.loc[tf_biggest_expr+tf_smallest_expr]

most_df_plot_nT = df_nT.loc[mean_row + tf_most_target_genes]
most_id_count_plot_nT = id_count_nT.loc[tf_most_target_genes]

# %%
# For T - instance
nan_array = np.empty(len(mean_per_tf_T_copy.columns))
nan_array[:] = np.NAN
nan_array

df_T = mean_per_tf_T_copy
df_T.loc['NR5A1'] = nan_array

id_count_T = tf_id_count_T
id_count_T["NR5A1"] = 0

all_target_count_T = len(gene_unique_T)



extreme_df_plot_T = df_T.loc[ mean_row + tf_biggest_expr+tf_smallest_expr]
extreme_id_count_plot_T = id_count_T.loc[tf_biggest_expr+tf_smallest_expr]

most_df_plot_T = df_T.loc[mean_row + tf_most_target_genes]
most_id_count_plot_T = id_count_T.loc[tf_most_target_genes]

# %%
# For nT - T
df_nT_T = df_nT - df_T
df_nT_T.loc["NR5A1"] = df_nT.loc["NR5A1"]

## GET all Target genes count
df_all_nT_T =  df_log_strand_red[(df_log_strand_red["homotypic_strand_orientation"] == 1) | (df_log_strand_red["homotypic_strand_orientation"] == -1)]

gene_unique_nT_T = df_all_nT_T[df_all_nT_T.groupby(["geneID"]).cumcount()==0]

# Analog zu id_count_nT + id_count_T
id_count_nT_T = df_all_nT_T.groupby(["tf"])["geneID"].nunique()


#extreme_df_plot_nT_T = df_nT_T.loc[ mean_row + tf_biggest_expr+tf_smallest_expr]
#extreme_id_count_plot_nT_T = id_count_nT_T.loc[tf_biggest_expr+tf_smallest_expr]

#most_df_plot_nT_T = df_nT_T.loc[mean_row + tf_most_target_genes]
#most_id_count_plot_nT_T = id_count_nT_T.loc[tf_most_target_genes]

# %% [markdown]
# ### Compare Paper

# %%
df3_count = tf_id_count_nT- tf_id_count_T
df3_count
# Out:
# tf
# AR         45
# ARNT     -101
# ARNTL       2
# ASCL1      21
# ATF2      -28
#          ...
# YY2       -47
# ZFX       -42
# ZNF143    349
# ZNF263    -63
# ZNF740     14
# Name: geneID, Length: 266, dtype: int64

# %%
# df_nT_T.drop('All Genes')
df_nT_T_pct = ( (df_nT - df_T) / ((df_nT + df_T)/2) )*100
df_nT - df_T
# Out:
#         Adipose - Subcutaneous  Adipose - Visceral (Omentum)  Adrenal Gland  \
# AR                    0.000000                      0.000000       0.000000
# ARNT                  0.000000                      0.000000       0.000000
# ARNTL                 0.000000                      0.000000       0.000000
# ASCL1                 0.000000                      0.000000       0.000000
# ATF2                  0.000000                      0.000000       0.000000
# ...                        ...                           ...            ...
# YY2                   0.752634                      0.700168       0.815150
# ZFX                  -0.122757                     -0.121980      -0.187590
# ZNF143               -0.461130                     -0.427094      -0.353215
# ZNF263               -0.451000                     -0.460772      -0.604894
# ZNF740                0.621571                      0.669401       0.712360
#
# ...

# %%
# all tfs
tfs = np.array(['AR', 'ARNT', 'ARNTL', 'ASCL1', 'ATF2', 'ATF3', 'ATF4', 'ATF7', 'BACH1', 'BACH2', 'BATF', 'BATF3', 'BCL6', 'BCL6B', 'BHLHE22', 'BHLHE40', 'CDX2', 'CEBPA', 'CEBPB', 'CEBPD', 'CEBPG', 'CLOCK', 'CREB1', 'CREM', 'CTCF', 'CTCFL', 'CUX1', 'DUX4', 'E2F1', 'E2F4', 'E2F6', 'E2F7', 'E2F8', 'EBF1', 'EBF3', 'EGR1', 'EGR2', 'EGR3', 'EHF', 'ELF1', 'ELF3', 'ELF4', 'ELF5', 'ELK1', 'ELK4', 'EOMES', 'ERF', 'ERG', 'ESR1', 'ESR2', 'ESRRA', 'ETS1', 'ETV1', 'ETV4', 'ETV5', 'ETV6', 'FLI1', 'FOS', 'FOSL1', 'FOSL2', 'FOXA1', 'FOXA2', 'FOXA3', 'FOXJ2', 'FOXK1', 'FOXK2', 'FOXO1', 'FOXP1', 'GABPA', 'GATA1', 'GATA2', 'GATA3', 'GATA4', 'GATA6', 'GFI1', 'GFI1B', 'GLIS1', 'GLIS2', 'GLIS3', 'GRHL2', 'HAND2', 'HIC1', 'HIF1A', 'HINFP', 'HLF', 'HMBOX1', 'HNF1A', 'HNF1B', 'HNF4A', 'HNF4G', 'HOXA9', 'HOXB13', 'HSF1', 'HSF2', 'IRF1', 'IRF2', 'IRF3', 'IRF4', 'ISL1', 'JUN', 'JUNB', 'JUND', 'KLF1', 'KLF11', 'KLF12', 'KLF15', 'KLF16', 'KLF4', 'KLF5', 'KLF9', 'LEF1', 'LHX2', 'LHX9', 'MAF', 'MAFB', 'MAFF', 'MAFK', 'MAX', 'MECOM', 'MEF2A', 'MEF2B', 'MEF2C', 'MEF2D', 'MEIS1', 'MEIS2', 'MGA', 'MITF', 'MLX', 'MNT', 'MXI1', 'MYB', 'MYBL2', 'MYC', 'MYCN', 'MYF5', 'MYOD1', 'MYOG', 'NEUROD1', 'NEUROG2', 'NFE2', 'NFE2L2', 'NFIA', 'NFIB', 'NFIC', 'NFIL3', 'NFKB1', 'NFKB2', 'NFYA', 'NFYB', 'NFYC', 'NKX2-5', 'NKX3-1', 'NR1H2', 'NR1H3', 'NR1H4', 'NR2C1', 'NR2C2', 'NR2F1', 'NR2F2', 'NR2F6', 'NR3C1', 'NR4A1', 'NR5A1', 'NR5A2', 'NRF1', 'OCT4', 'ONECUT1', 'ONECUT2', 'OSR2', 'OTX2', 'PAX5', 'PAX6', 'PBX1', 'PBX2', 'PBX3', 'PDX1', 'PHOX2B', 'PKNOX1', 'PLAG1', 'POU2F1', 'POU2F2', 'POU5F1', 'PPARG', 'PRDM1', 'PRDM4', 'RARA', 'RARG', 'RBPJ', 'REL', 'RELA', 'RELB', 'REST', 'RFX1', 'RFX2', 'RFX3', 'RFX5', 'RUNX1', 'RUNX2', 'RUNX3', 'RXRA', 'RXRB', 'SCRT1', 'SCRT2', 'SIX1', 'SIX2', 'SMAD2', 'SMAD3', 'SMAD4', 'SNAI2', 'SOX10', 'SOX13', 'SOX17', 'SOX2', 'SOX4', 'SOX6', 'SOX9', 'SP1', 'SP2', 'SP3', 'SP4', 'SPDEF', 'SPI1', 'SPIB', 'SREBF1', 'SRF', 'STAT1', 'STAT2', 'STAT3', 'STAT4', 'STAT5A', 'STAT5B', 'STAT6', 'T', 'TAL1', 'TBX21', 'TBX5', 'TCF12', 'TCF3', 'TCF4', 'TCF7', 'TCF7L1', 'TCF7L2', 'TEAD1', 'TEAD3', 'TEAD4', 'TFAP2A', 'TFAP2C', 'TFAP4', 'TFDP1', 'TFE3', 'TFEB', 'THAP11', 'THRB', 'TP53', 'TP63', 'TP73', 'TWIST1', 'USF1', 'USF2', 'VDR', 'WT1', 'XBP1', 'YY1', 'YY2', 'ZFX', 'ZNF143', 'ZNF263', 'ZNF740'])

# %%
# homotypic TFBS Paper
diff_paper = np.array(["ARNT", "FOXA1", "HNF4A", "NR2F2", "ONECUT1", "REST", "RXRA", "SP1", "TFAP2C", "XBP1", "YY1"])
no_diff_paper = np.array(["CEBPA", "HNF1A" ,"CTCF", "CREB1", "GABPA"])
human_effekt_paper = np.array(["CTCF", "FOXA1", "HNF4A", "RXRA", "YY1"])

# %%
#increase_paper = np.array(["CEBPA", "HNF1A", "HNF4A","SP1"])
#no_effekt_paper = np.array(["ARNT",  "NR2F2", "RXRA"])

# %%
liver_paper = np.array(["ARNT", "CEBPA", "FOXA1", "HNF1A", "HNF4A", "NR2F2", "ONECUT1", "RXRA", "TFAP2C", "XBP1"])
general_paper = np.array(["CTCF", "YY1", "SP1", "CREB1", "REST" ,"GABPA"])

# %%
#liver_paper = np.array(["ARNT", "CEBPA", "HNF1A", "HNF4A", "NR2F2", "RXRA", "TFAP2C"])
#general_paper = np.array(["CTCF", "YY1", "SP1", "CREB1", "REST" ,"GABPA"])

# %%
df_nT_T["Liver"].loc[no_diff_paper], df3_count.loc[no_diff_paper]
# Out:
# (CEBPA    10.376366
#  HNF1A     4.148831
#  CTCF     -8.644438
#  CREB1    -3.043694
#  GABPA    -0.176665
#  Name: Liver, dtype: float64,
#  tf
#  CEBPA    -34
#  HNF1A     -2
#  CTCF     357
#  CREB1     -2
#  GABPA     26
#  Name: geneID, dtype: int64)

# %%
df_nT_T["Liver"].loc[list(liver_paper) + list(general_paper)].sort_values(key=lambda x: abs(x))
# Out:
# GABPA      -0.176665
# REST       -0.602862
# ARNT        1.637356
# NR2F2       1.863350
# HNF4A      -1.911014
# XBP1        2.125559
# CREB1      -3.043694
# HNF1A       4.148831
# FOXA1      -4.524385
# TFAP2C     -4.536682
# RXRA       -6.512268
# YY1         8.143948
# CTCF       -8.644438
# SP1         9.038335
# CEBPA      10.376366
# ONECUT1   -22.251657
# Name: Liver, dtype: float64

# %%
df_nT_T["Liver"].loc[diff_paper].sort_values(key=lambda x: abs(x)), df3_count.loc[diff_paper]
# Out:
# (REST       -0.602862
#  ARNT        1.637356
#  NR2F2       1.863350
#  HNF4A      -1.911014
#  XBP1        2.125559
#  FOXA1      -4.524385
#  TFAP2C     -4.536682
#  RXRA       -6.512268
#  YY1         8.143948
#  SP1         9.038335
#  ONECUT1   -22.251657
#  Name: Liver, dtype: float64,
#  tf
#  ARNT      -101
#  FOXA1      232
#  HNF4A      122
#  NR2F2        5
#  ONECUT1    -10
#  REST       188
#  RXRA       132
#  SP1        153
#  TFAP2C       9
#  XBP1         2
#  YY1         65
#  Name: geneID, dtype: int64)

# %%
df_nT_T["Liver"].loc[human_effekt_paper], df3_count.loc[human_effekt_paper]
# Out:
# (CTCF    -8.644438
#  FOXA1   -4.524385
#  HNF4A   -1.911014
#  RXRA    -6.512268
#  YY1      8.143948
#  Name: Liver, dtype: float64,
#  tf
#  CTCF     357
#  FOXA1    232
#  HNF4A    122
#  RXRA     132
#  YY1       65
#  Name: geneID, dtype: int64)

# %%
df_nT_T.loc[general_paper].var(axis=1), df3_count.loc[general_paper]
# Out:
# (CTCF     5.993381
#  YY1      3.971504
#  SP1      7.113542
#  CREB1    7.212617
#  REST     1.924218
#  GABPA    1.352058
#  dtype: float64,
#  tf
#  CTCF     357
#  YY1       65
#  SP1      153
#  CREB1     -2
#  REST     188
#  GABPA     26
#  Name: geneID, dtype: int64)

# %%
df_nT_T.loc[liver_paper].var(axis=1), df3_count.loc[liver_paper]
# Out:
# (ARNT       0.000000
#  CEBPA      0.000000
#  FOXA1      0.000000
#  HNF1A      0.000008
#  HNF4A      0.000000
#  NR2F2      0.000000
#  ONECUT1    0.067725
#  RXRA       0.009838
#  TFAP2C     0.008801
#  XBP1       0.036595
#  dtype: float64,
#  tf
#  ARNT      -101
#  CEBPA      -34
#  FOXA1      232
#  HNF1A       -2
#  HNF4A      122
#  NR2F2        5
#  ONECUT1    -10
#  RXRA       132
#  TFAP2C       9
#  XBP1         2
#  Name: geneID, dtype: int64)

# %% [markdown]
# #### Plot extreme

# %%
df1 = extreme_df_plot_nT
df2 = extreme_df_plot_T
df3 = extreme_df_plot_nT_T

df1_count = extreme_id_count_plot_nT
df2_count = extreme_id_count_plot_T
df3_count = extreme_id_count_plot_nT_T

df3_count = extreme_id_count_plot_nT - extreme_id_count_plot_T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 df1 = extreme_df_plot_nT
#       2 df2 = extreme_df_plot_T
#       3 df3 = extreme_df_plot_nT_T
#
# NameError: name 'extreme_df_plot_nT' is not defined

# %%
df1 = most_df_plot_nT
df2 = most_df_plot_T
df3 = most_df_plot_nT_T

df1_count = most_id_count_plot_nT
df2_count = most_id_count_plot_T
df3_count = most_id_count_plot_nT - most_id_count_plot_T

# %%
df3.min().min()
df3.max().max()
# Out:
# 5.7366048753142485

# %%
max(abs(df3.min().min()), abs(df3.max().max()))
# Out:
# 6.811015404648103

# %%
# extreme
value_min = 1.4
value_max = 4.3

value_min_diff = -max(abs(df3.min().min()), abs(df3.max().max()))
value_max_diff = max(abs(df3.min().min()), abs(df3.max().max()))

# %%
#most
value_min = 1.4
value_max = 4.3

value_min_diff = -max(abs(df3.min().min()), abs(df3.max().max()))
value_max_diff = max(abs(df3.min().min()), abs(df3.max().max()))

# %%
my_cmap = plt.get_cmap("viridis").copy()
my_cmap.set_over("#FFFF99")
my_cmap.set_under("#000033")
norm = mpl.colors.Normalize(vmin= value_min, vmax= value_max)


my_cmap2 = plt.get_cmap("coolwarm").copy()
norm2 = mpl.colors.Normalize(vmin= value_min_diff, vmax= value_max_diff)

# %%
asp = (df1.shape[0] + df2.shape[0] + df3.shape[0]) /float(df1.shape[1])
figw = 13
figh = figw*asp


gridspec_kw = {"height_ratios":[len(df1),len(df2), len(df3)], "width_ratios" : [54,1]}
heatmapkws = dict(square=False, cbar=False,  cmap=my_cmap, fmt=".2f", linewidths=0.01, vmin= value_min, vmax= value_max, robust=True)
heatmapkws_diff = dict(square=False, cbar=False,  cmap=my_cmap2, fmt=".2f", linewidths=0.01, vmin= value_min_diff, vmax= value_max_diff, robust=True)


fig, axes = plt.subplots(ncols=2, nrows=3, figsize=(figw, figh), gridspec_kw=gridspec_kw)

# left = 0.07; right=0.87
# bottom = 0.1; top = 0.9

plt.subplots_adjust(wspace=0.06, hspace=0.1)


# sns.heatmap(mean_log2_expr_per_tissue_copy, cmap=my_cmap, fmt=".2f", linewidths=0.01, cbar_kws={"orientation": "horizontal", "location":"top", "label":"$log_2$(Gene Expression)", "extend":"both"}, vmin= value_min, vmax= value_max, robust=True)
 ## nT
# Mean over all Target genes - column
sns.heatmap(df1.iloc[1:,54:], ax=axes[0,1], xticklabels=True, yticklabels=True,  **heatmapkws)
# Normal heatmap
sns.heatmap(df1.iloc[1:,:54], ax=axes[0,0], xticklabels=True, yticklabels=True,  **heatmapkws)
# mean gene expr over all
#sns.heatmap(extreme_df_plot.iloc[:1,54:], ax=axes[0,1], xticklabels=True, yticklabels=True,  **heatmapkws)

 ## T
# Mean over all Target genes - column
sns.heatmap(df2.iloc[1:,54:], ax=axes[1,1], xticklabels=True, yticklabels=True,  **heatmapkws)
# Normal heatmap
sns.heatmap(df2.iloc[1:,:54], ax=axes[1,0], xticklabels=True, yticklabels=True,  **heatmapkws)
# mean gene expr over all
#sns.heatmap(extreme_df_plot.iloc[:1,54:], ax=axes[0,1], xticklabels=True, yticklabels=True,  **heatmapkws)

 ## nT - T

# Mean over all Target genes - column
sns.heatmap(df3.iloc[1:,54:], ax=axes[2,1], xticklabels=True, yticklabels=True,  **heatmapkws_diff)
# Normal heatmap
sns.heatmap(df3.iloc[1:,:54], ax=axes[2,0], xticklabels=True, yticklabels=True,  **heatmapkws_diff)



# axes[0,0].set_xlabel('Tissues')
axes[0,0].set_ylabel('$( nT )$', rotation=0, labelpad = 30)
axes[1,0].set_ylabel('$(T)$', rotation=0, labelpad = 30)
axes[2,0].set_ylabel('$(nT - T)$', rotation=0, labelpad = 30)

# Tissues:
# oben mean tissues, x-ticks rotieren und nach oben, unten weg, y-ticks auf keine rotation
axes[0,0].tick_params(axis="x",top=True,labeltop=True, labelbottom=False, bottom=False, labelrotation=90)
axes[0,0].tick_params(axis="y", labelrotation=0)

## Df 1
# kleines rechteck oben rechts, x ticks drehen und nach oben, unten entfernen, y1-ticks entfernen, y2-ticks auf rechte seite durch len(df_red) also anzahl Target gene insgesamt
axes[0,1].tick_params(axis="x",top=True,labeltop=True, labelbottom=False, bottom=False, labelrotation=90)
axes[0,1].tick_params(axis="y", labelrotation=90)
#axes[0,1].set_ylim([0,axes[0,1].get_ylim()[0]])
axes[0,1].set_yticks(axes[0,1].get_yticks())
axes[0,1].set_yticklabels(df1_count.values) ### target Gene count df1 
axes[0,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)

## Df 2 
# Main Heatmap, x ticks entfernen, y-ticks lassen
axes[1,0].set_xticklabels([])
axes[1,0].set_xticks([])

# rechte lange Spalte
# Hinzufügern der y2-beschriftung mit tf_id_count, entfernen der y1-ticks etc, entfernen der x-ticks
axes[1,1].set_yticks(axes[1,1].get_yticks())
axes[1,1].set_yticklabels(df2_count.values) ### target Gene count df2 
axes[1,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)
axes[1,1].set_xticklabels([])
axes[1,1].set_xticks([])


## Df 3

#axes[2,0].set_ylabel('$(b)$', rotation=0, labelpad = 20)
# Main Heatmap, x ticks entfernen, y-ticks lassen
axes[2,0].set_xticklabels([])
axes[2,0].set_xticks([])

# rechte lange Spalte
# Hinzufügern der y2-beschriftung mit tf_id_count, entfernen der y1-ticks etc, entfernen der x-ticks
axes[2,1].set_yticks(axes[2,1].get_yticks())
axes[2,1].set_yticklabels(df3_count.values) ### target Gene count df3
axes[2,1].tick_params(axis="y", left=False, labelleft=False, right=True, labelright=True, labelrotation=0)
axes[2,1].set_xticklabels([])
axes[2,1].set_xticks([])


# Colorbar
# cax = fig.add_axes([0.12, 0.9, 0.8, 0.01])
cax = fig.add_axes([0.97,0.39,0.05,0.5])
sm = mpl.cm.ScalarMappable(cmap=my_cmap, norm=norm)
sm.set_array([])
fig.colorbar(sm, cax=cax, extend='both', location="right", label="$log_2$(Gene Expression)")


# Colorbar DIFF
# cax = fig.add_axes([0.12, 0.9, 0.8, 0.01])
cax2 = fig.add_axes([0.97,0.125,0.05,0.2])
sm2 = mpl.cm.ScalarMappable(cmap=my_cmap2, norm=norm2)
sm2.set_array([])
fig.colorbar(sm2, cax=cax2, location="right", label="$log_2$(Gene Expression)")

# plt.tight_layout()
#plt.savefig(r"images_BA/nT_T_heatmap_extreme.pdf", bbox_inches = 'tight')
#plt.savefig(r"images_BA/nT_T_heatmap_most.pdf", bbox_inches = 'tight')

# %% [markdown]
# ## Split Genes into nT - T

# %%
unique_strand = df_combined_log.groupby(["geneID"])["strand_orientation"].nunique()
unique_strand.values
# Out:
# array([1, 2, 2, ..., 1, 2, 1])

# %%
nT_or_T_genes = unique_strand[unique_strand == 1]
nT_or_T_genes
# Out:
# geneID
# ENSG00000000003.14    1
# ENSG00000002745.12    1
# ENSG00000003096.14    1
# ENSG00000003137.8     1
# ENSG00000004139.13    1
#                      ..
# ENSG00000283473.2     1
# ENSG00000284018.1     1
# ENSG00000284024.1     1
# ENSG00000284484.1     1
# ENSG00000284546.1     1
# Name: strand_orientation, Length: 1528, dtype: int64

# %%
df_nT_or_T_genes = df_combined_log[np.isin(df_combined_log["geneID"], nT_or_T_genes.index)]

# %%
# Filter tfs and homotypic tfs out. Every gene only once
df_nT_or_T_genes_red = df_nT_or_T_genes[df_nT_or_T_genes.groupby(["geneID"]).cumcount() == 0]

# %%
genes_nT = df_nT_or_T_genes_red[df_nT_or_T_genes_red["strand_orientation"] == "nT"]
genes_T = df_nT_or_T_genes_red[df_nT_or_T_genes_red["strand_orientation"] == "T"]

# %%
expr_nT = genes_nT.iloc[:,9:]
expr_T = genes_T.iloc[:,9:]

# %%
expr_nT.mean().mean()
# Out:
# 0.3785873039292681

# %%
expr_T.mean().mean()
# Out:
# 0.5900865546208808

# %%
len(genes_nT), len(genes_T)
# Out:
# (747, 781)

# %%
value_min = min(expr_nT.mean().min(), expr_nT.mean().min())
value_max = max(expr_T.mean().max(), expr_T.mean().max())

my_cmap = plt.get_cmap("viridis").copy()
# my_cmap.set_over("#FFFF99")
# my_cmap.set_under("#000033")
norm = mpl.colors.Normalize(vmin= value_min, vmax= value_max)

heatmapkws = dict(square=False, cbar=False,  cmap=my_cmap, fmt=".2f", linewidths=0.01, vmin= value_min, vmax= value_max)



fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(3,10))
plt.subplots_adjust( wspace=2)

secax0 = axes[0].twinx()
# secax1 = axes[1].twinx()
# secax2 = axes[2].twinx()

# target-genes
sns.heatmap(expr_nT.mean().to_frame(name="non-Template"), ax=axes[0], xticklabels=True, yticklabels=True,  **heatmapkws)
sns.heatmap(expr_nT.mean().to_frame(name="non-Template"), ax=secax0, xticklabels=True, yticklabels=True,  **heatmapkws)

# all genes
#sns.heatmap( gtex_expr_log_filter_NA_rows.mean().to_frame(name="All GTEx Genes"), ax=axes[2], xticklabels=True, yticklabels=True,  **heatmapkws)
# sns.heatmap(mean_gtex_expr_log.to_frame(name="All GTEx Genes"), ax=secax1, xticklabels=True, yticklabels=False,  **heatmapkws)

# non-target-genes 
sns.heatmap(expr_T.mean().to_frame(name="Template"), ax=axes[1], xticklabels=True, yticklabels=True,  **heatmapkws)
# sns.heatmap(not_target_gtex_df["meanExpr"].to_frame("non-Target Genes"), ax=secax2, xticklabels=True, yticklabels=False,  **heatmapkws)

# AXIS 1
## Set first y_axis
axes[0].set_ylabel('Tissues')

## Set first x axis
#axes[0].tick_params(axis="x", top=True, labeltop=True, labelbottom=False, bottom=False)

## Set secondary y_axis
#secax0.set_ylim([0,axes[0].get_ylim()[0]])
secax0.set_yticks(axes[0].get_yticks())
secax0.set_ylabel("# Genes")
secax0.set_yticklabels(expr_nT.count()) # Target Gene Count

## Set secondary x axis
secax0.tick_params(axis="x", top=False, labeltop=False, labelbottom=True, bottom=True)


# AXIS 2
## Set y_axis
#axes[2].tick_params(axis="y", right=True, left=False, labelleft=False, labelright = True, labelrotation=0)
#axes[2].set_yticklabels(gtex_expr_log_filter_NA_rows.count())
#axes[2].yaxis.set_label_position("right")
#axes[2].set_ylabel("# GTEx Genes")

# AXIS 3
## Set y_axis
axes[1].tick_params(axis="y", right=True, left=False, labelleft=False, labelright =True, labelrotation=0)
axes[1].set_yticklabels(expr_T.count())
axes[1].yaxis.set_label_position("right")
axes[1].set_ylabel("# Genes")



# COLORBAR
cax = fig.add_axes([0.1,0.9,0.9,0.03])
sm = mpl.cm.ScalarMappable(cmap=my_cmap, norm=norm)
sm.set_array([])
fig.colorbar(sm, cax=cax, orientation="horizontal", location="top", label="$log_2$(Gene Expression)")

#plt.savefig("images_BA/strand_heatmap_mean.pdf", bbox_inches = 'tight')

# %% [markdown]
# # Old

# %%
def transform_expr_to_log_zero_to_nan(df, expr_iloc_start=9, expr_iloc_end=None):
    if expr_iloc_end is None:
        expr_iloc_end = len(df.columns)
    expr = df.iloc[:,expr_iloc_start:expr_iloc_end]
    replace_zero = expr.replace(0, np.NAN)
    expr_log2 = np.log2(replace_zero)
    df_new = df.copy()
    df_new.iloc[:,expr_iloc_start:expr_iloc_end] = expr_log2
    return df_new

def flatten_tissues_expand_df(tfbs_df, tissue_iloc =9):
    tfbs_part_repeat = tfbs_df.iloc[:,:tissue_iloc]
    tfbs_part_flatten = tfbs_df.iloc[:,tissue_iloc:]
    
    repeat_df =  pd.DataFrame(np.repeat(tfbs_part_repeat.values, tfbs_part_flatten.shape[1], axis=0))
    repeat_df = repeat_df.convert_dtypes(convert_integer = True)
    
    
    flatten_arr = tfbs_part_flatten.to_numpy().flatten()

    tissue_repeat = np.tile(np.array(tfbs_part_flatten.columns), len(tfbs_part_repeat))
    
    repeat_df.columns = tfbs_part_repeat.columns
    repeat_df["GeneExpr"] = flatten_arr
    repeat_df["Tissue"] = tissue_repeat
    
    return repeat_df

def get_mean_expression_per_tf(df_flat, x="log2_GeneExpr"):
    return df_flat.groupby(["tf"])[x].mean()

# %%
# Transform all GeneExpression values to log2(GeneExpr)
df_log = transform_expr_to_log_zero_to_nan(df_combined)

# %%
# Function to add a new column labeling the Stran-Orientation for the TFBSs

def add_strand_orientation_pct(df):
    """
    Calculates the fraction for TFBS occurences for each TFBS and adds a new column at the end of the DataFrame.
    1 = all non-Template Strand 
    -1 =  all Template strand
    """
    df_change = df.copy()
    df_change["strand_orientation"] = np.array([1 if i == "nT" else -1 for i in df["strand_orientation"]])
    mean_orientation_arr = df_change.groupby(by=["tf", "geneID", "homotypic_count"])["strand_orientation"].transform("mean")
    df_strand = df.copy()
    df_strand.insert(loc=6, column="homotypic_strand_orientation", value=mean_orientation_arr)
    return df_strand

# %%
df_log_strand = add_strand_orientation_pct(df_log)

# %%
df_log_strand
# Out:
#           chr              geneID      tf  close_tss  dist_tss  \
# 0        chr1  ENSG00000163209.14  HMBOX1        159       169
# 1        chr1  ENSG00000143569.18  HMBOX1          9        19
# 2       chr10  ENSG00000213390.10  HMBOX1         47        57
# 3        chr1  ENSG00000169241.17  HMBOX1        160       170
# 4        chr1  ENSG00000185499.16  HMBOX1        173       183
# ...       ...                 ...     ...        ...       ...
# 700911   chr7  ENSG00000105851.10  STAT5B         -3         8
# 700912   chr7  ENSG00000075790.10  STAT5B        124       135
# 700913   chr7   ENSG00000128590.4  STAT5B         54        69
# 700914   chr7   ENSG00000198839.9  STAT5B         56        71
# 700915   chr7  ENSG00000128512.20  STAT5B        105       120
#
#        strand_orientation  homotypic_strand_orientation  homotypic_count  \
# 0                      nT                           1.0                1
# ...

# %% [markdown]
# # Flat

# %%
# Flatten Tissue for all 
df_log_flat = flatten_tissues_expand_df(df_log_strand)

# %% [markdown]
# ## Rest

# %%
def add_strand_orientation_pct(df):
    """
    Calculates the fraction for TFBS occurences for each TFBS and adds a new column at the end of the DataFrame.
    1 = all non-Template Strand 
    -1 =  all Template strand
    """
    df_change = df.copy()
    df_change["strand_orientation"] = np.array([1 if i == "nT" else -1 for i in df["strand_orientation"]])
    mean_orientation_arr = df_change.groupby(by=["tf", "geneID", "homotypic_count"])["strand_orientation"].transform("mean")
    df_strand = df.copy()
    df_strand.insert(loc=6, column="homotypic_strand_orientation", value=mean_orientation_arr)
    return df_strand

# %%
df_strand = add_strand_orientation_pct(df_combined)

# %%
df_strand
# Out:
#           chr              geneID      tf  close_tss  dist_tss  \
# 0        chr1  ENSG00000163209.14  HMBOX1        159       169
# 1        chr1  ENSG00000143569.18  HMBOX1          9        19
# 2       chr10  ENSG00000213390.10  HMBOX1         47        57
# 3        chr1  ENSG00000169241.17  HMBOX1        160       170
# 4        chr1  ENSG00000185499.16  HMBOX1        173       183
# ...       ...                 ...     ...        ...       ...
# 700911   chr7  ENSG00000105851.10  STAT5B         -3         8
# 700912   chr7  ENSG00000075790.10  STAT5B        124       135
# 700913   chr7   ENSG00000128590.4  STAT5B         54        69
# 700914   chr7   ENSG00000198839.9  STAT5B         56        71
# 700915   chr7  ENSG00000128512.20  STAT5B        105       120
#
#        strand_orientation  homotypic_strand_orientation  homotypic_count  \
# 0                      nT                           1.0                1
# ...

# %% [markdown]
# ## Pearson correlation of homotypic strand percent against Geneexpression

# %%
def refine_pearson_df(df):
    # Which TFBS have only one TFBS per Promotor?
    na_r = df.Pearson_r.isna().to_numpy()
    filterd_constant = df[na_r].TFs.to_numpy()
    print(f"{len(filterd_constant)} were filtered because they have  a constant homotypic count.")

    pearson_df_sort = df.reindex(df["Pearson_r"].abs().sort_values(ascending=False).index).dropna()
    pearson_df_sort_pval = pearson_df_sort[pearson_df_sort["Pearson_p"] < 0.05]
    pearson_df_sort_pval["Pearson_p"] = -np.log10(pearson_df_sort_pval["Pearson_p"])

    # TFBS filterd out through p_value
    filtered_tfbs = pearson_df_sort[pearson_df_sort["Pearson_p"] >= 0.05]
    filtered_by_p = filtered_tfbs.TFs.to_numpy()
    print(f"{len(filtered_by_p)} were filtered because they have  a p-value < 0.05.")

    return pearson_df_sort_pval, filterd_constant, filtered_by_p

# %% [markdown]
# ### Flat

# %%
def flatten_tissues_expand_df(tfbs_df, tissue_iloc =9):
    tfbs_part_repeat = tfbs_df.iloc[:,:tissue_iloc]
    tfbs_part_flatten = tfbs_df.iloc[:,tissue_iloc:]
    
    repeat_df =  pd.DataFrame(np.repeat(tfbs_part_repeat.values, tfbs_part_flatten.shape[1], axis=0))
    flatten_arr = tfbs_part_flatten.to_numpy().flatten()

    tissue_repeat = np.tile(np.array(tfbs_part_flatten.columns), len(tfbs_part_repeat))
    
    repeat_df.columns = tfbs_part_repeat.columns
    repeat_df["GeneExpr"] = flatten_arr
    repeat_df["Tissue"] = tissue_repeat
    
    return repeat_df


def get_pearson(df, x="homotypic_count", tissue="GeneExpr"):
    tfs = df["tf"].unique()
    r_lst = []
    p_lst = []
    tf_lst = []
    for tf in tfs:
        df_tf = df[df["tf"] == tf]
        if len(df_tf) >= 2:
            r, p_value = pearsonr(df_tf[x], np.array(df_tf[tissue]))
            r_lst.append(r)
            p_lst.append(p_value)
            tf_lst.append(tf)
        else:
            print(f"{tf} has less then 2 entrys. No Correlation could be calculated")
    pearson_df = pd.DataFrame({"TFs":tf_lst, "Pearson_r":r_lst, "Pearson_p":p_lst})

    return pearson_df

# %%
def reduce_homotypic_tfbs_occurence_consider_strand(df):
    occur_region = df.groupby(["chr", "geneID", "tf", "homotypic_count", "Tissue"]).cumcount()
    df_red = df[occur_region == 0]
    return df_red

# %%
#flat_strand_df = flatten_tissues_expand_df(df_strand, tissue_iloc=10)c
#flat_strand_df_red = reduce_homotypic_tfbs_occurence_consider_strand(flat_strand_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 flat_strand_df = flatten_tissues_expand_df(df_strand, tissue_iloc=10)
#       2 flat_strand_df_red = reduce_homotypic_tfbs_occurence_consider_strand(flat_strand_df)
#
# NameError: name 'df_strand' is not defined

# %%
# NEW

flat_strand_df = flatten_tissues_expand_df(df_log_strand, tissue_iloc=10)
flat_strand_df_red = reduce_homotypic_tfbs_occurence_consider_strand(flat_strand_df)

# %%
flat_strand_df_red
# Out:
#            chr              geneID      tf close_tss dist_tss  \
# 0         chr1  ENSG00000163209.14  HMBOX1       159      169
# 1         chr1  ENSG00000163209.14  HMBOX1       159      169
# 2         chr1  ENSG00000163209.14  HMBOX1       159      169
# 3         chr1  ENSG00000163209.14  HMBOX1       159      169
# 4         chr1  ENSG00000163209.14  HMBOX1       159      169
# ...        ...                 ...     ...       ...      ...
# 37845841  chr7  ENSG00000128512.20  STAT5B       105      120
# 37845842  chr7  ENSG00000128512.20  STAT5B       105      120
# 37845843  chr7  ENSG00000128512.20  STAT5B       105      120
# 37845844  chr7  ENSG00000128512.20  STAT5B       105      120
# 37845845  chr7  ENSG00000128512.20  STAT5B       105      120
#
#          strand_orientation homotypic_strand_orientation homotypic_count  \
# 0                        nT                          1.0               1
# ...

# %% [markdown]
# ### Homotypic strand orientation VS. Flat-GeneExpr

# %%
pearson_strand_df = get_pearson(flat_strand_df_red, x="homotypic_strand_orientation")
# Out:
# /sybig/home/jme/Bachelorarbeit/.venv/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
pearson_strand_df.to_csv("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/strand_pct_Pearson.csv", index=False)

# %%
pearson_df_sort_pval, filterd_constant, filtered_by_p = refine_pearson_df(pearson_strand_df)
# Out:
# 1 were filtered because they have  a constant homotypic count.
# 66 were filtered because they have  a p-value < 0.05.
# /tmp/ipykernel_2113880/129602368.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pearson_df_sort_pval["Pearson_p"] = -np.log10(pearson_df_sort_pval["Pearson_p"])

# %%
pearson_df_sort_pval
# Out:
#         TFs  Pearson_r  Pearson_p
# 233   ARNTL   0.256436  79.506366
# 236  POU2F1   0.214196   6.296585
# 26    SOX10  -0.189905   3.229528
# 121    RFX2   0.185116  17.791833
# 237    ISL1   0.168632  11.764249
# ..      ...        ...        ...
# 154  NFE2L2  -0.004393   1.347982
# 144    REST  -0.004168   1.675244
# 189   RUNX1  -0.003471   1.605991
# 145    ESR1   0.003352   1.731789
# 10       AR   0.003207   1.309109
#
# [200 rows x 3 columns]

# %% [markdown]
# #### Plot

# %%
fig, ax = plt.subplots(figsize=(10,40))

norm = plt.Normalize(pearson_df_sort_pval["Pearson_p"].min(), pearson_df_sort_pval["Pearson_p"].max())
sm = plt.cm.ScalarMappable(cmap="rocket_r", norm=norm)

sns.barplot(pearson_df_sort_pval, x="Pearson_r", y="TFs",hue="Pearson_p", width=0.5, palette="rocket_r")


ax.set_ylabel('TFBS')

ax.xaxis.tick_top()
ax.set_xlabel('Pearson Correlation')
ax.xaxis.set_label_position("top")

ax.xaxis.grid(True)
ax.get_legend().remove()

plt.subplots_adjust(top=0.9)
cbar = ax.figure.colorbar(sm, ax=ax, orientation= "horizontal", location="top")
cbar.set_label("-log10(p-value)")

#fig.savefig("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/Boxplot/strand_ratio_Pearson_corr.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 fig, ax = plt.subplots(figsize=(10,40))
#       3 norm = plt.Normalize(pearson_df_sort_pval["Pearson_p"].min(), pearson_df_sort_pval["Pearson_p"].max())
#       4 sm = plt.cm.ScalarMappable(cmap="rocket_r", norm=norm)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### Filter for all nT (1) and all T (-1) VS. homotypic count

# %%
filtered_all_nT = flat_strand_df_red[flat_strand_df_red["homotypic_strand_orientation"]== 1]
filtered_all_T = flat_strand_df_red[flat_strand_df_red["homotypic_strand_orientation"]== -1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 filtered_all_nT = flat_strand_df_red[flat_strand_df_red["homotypic_strand_orientation"]== 1]
#       2 filtered_all_T = flat_strand_df_red[flat_strand_df_red["homotypic_strand_orientation"]== -1]
#
# NameError: name 'flat_strand_df_red' is not defined

# %%
pearson_all_nT = get_pearson(filtered_all_nT)
pearson_all_T = get_pearson(filtered_all_T)
# Out:
# /sybig/home/jme/Bachelorarbeit/.venv/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
pearson_all_nT.to_csv("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/all_nT_Pearson.csv", index=False)
pearson_all_T.to_csv("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/all_T_Pearson.csv", index=False)

# %%
nT_pearson_sort_pval, nT_filterd_constant, nT_filtered_by_p = refine_pearson_df(pearson_all_nT)
# Out:
# 84 were filtered because they have  a constant homotypic count.
# 76 were filtered because they have  a p-value < 0.05.
# /tmp/ipykernel_2124244/129602368.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pearson_df_sort_pval["Pearson_p"] = -np.log10(pearson_df_sort_pval["Pearson_p"])

# %%
T_pearson_sort_pval, T_filterd_constant, T_filtered_by_p = refine_pearson_df(pearson_all_T)
# Out:
# 81 were filtered because they have  a constant homotypic count.
# 62 were filtered because they have  a p-value < 0.05.
# /tmp/ipykernel_2124244/129602368.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pearson_df_sort_pval["Pearson_p"] = -np.log10(pearson_df_sort_pval["Pearson_p"])

# %%
T_filtered_by_p.sort()
T_filtered_by_p
# Out:
# array(['ASCL1', 'ATF2', 'ATF3', 'ATF4', 'ATF7', 'BATF', 'BCL6', 'CDX2',
#        'CREM', 'CTCF', 'DUX4', 'E2F4', 'EOMES', 'ERG', 'ESRRA', 'ETV1',
#        'FOS', 'FOSL1', 'FOSL2', 'FOXA1', 'FOXA2', 'GATA2', 'GLIS1',
#        'HAND2', 'HNF1A', 'JUNB', 'JUND', 'LEF1', 'MAFF', 'MEF2B', 'MEIS1',
#        'MITF', 'MYCN', 'NFIC', 'NFIL3', 'NFKB1', 'NFKB2', 'NFYB', 'NR2C2',
#        'ONECUT2', 'PDX1', 'POU5F1', 'RBPJ', 'REST', 'RXRA', 'SIX1',
#        'SOX13', 'SPIB', 'SREBF1', 'STAT1', 'STAT5A', 'TBX21', 'TBX5',
#        'TCF12', 'TCF3', 'TCF7', 'TEAD1', 'TFAP2C', 'TP73', 'YY1', 'YY2',
#        'ZNF143'], dtype=object)

# %% [markdown]
# #### Plot

# %%
fig, ax = plt.subplots(figsize=(10,23))

norm = plt.Normalize(T_pearson_sort_pval["Pearson_p"].min(), T_pearson_sort_pval["Pearson_p"].max())
sm = plt.cm.ScalarMappable(cmap="rocket_r", norm=norm)

sns.barplot(T_pearson_sort_pval, x="Pearson_r", y="TFs",hue="Pearson_p", width=0.5, palette="rocket_r")


ax.set_ylabel('TFBS')

ax.xaxis.tick_top()
ax.set_xlabel('Pearson Correlation')
ax.xaxis.set_label_position("top")

ax.xaxis.grid(True)
ax.get_legend().remove()

plt.subplots_adjust(top=0.9)
cbar = ax.figure.colorbar(sm, ax=ax, orientation= "horizontal", location="top", )
cbar.set_label("-log10(p-value)")

#fig.savefig("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/Boxplot/T_Pearson_homoCount_Expr.png")

# %%
# Table
print(T_pearson_sort_pval[T_pearson_sort_pval["Pearson_r"] > 0.05])
# Out:
#         TFs  Pearson_r  Pearson_p
# 235  POU2F2   0.125779  81.406493
# 47    SOX17   0.102589  21.679886
# 136   PRDM1   0.085749  26.487226
# 35   HOXB13   0.079833  35.760394
# 170   NR2C1   0.076655  24.890651
# 175  TWIST1   0.073217  33.137693
# 28     NFE2   0.072078  45.840222
# 173    PBX2   0.070202  69.124495
# 216   RUNX2   0.064363  60.067120
# 60     KLF1   0.059941  64.131997
# 148   CEBPG   0.058541  21.658866
# 245    TCF4   0.053581  28.592657
# 137   GRHL2   0.052059  32.844346
# 152   FOXP1   0.050801  20.285796
# 195   MYOD1   0.050293  21.819514

# %% [markdown]
# ### All Tissues

# %%
def get_pearson_all_tissues(df, columns="homotypic_count", expr_start_iloc=9, expr_end_iloc=None):
    # default argument for expr_end_iloc
    if expr_end_iloc is None:
        expr_end_iloc = len(df.columns)
    


    tfs = df["tf"].unique()
    tissues = np.array(df.columns[expr_start_iloc:expr_end_iloc])
    
    # initialize Array with shape (0,54), This is important to vstack the 1D-Arrays for every tf, to genereate a 2D-array.
    r_all_tf = np.zeros([0,len(tissues)])
    p_all_tf = np.zeros([0,len(tissues)])

    tfs_lst = []
    for tf in tfs:
        df_tf = df[df["tf"] == tf]
        if len(df_tf) > 1:
            tfs_lst.append(tf)

            tfbs_counts = np.array(df_tf["homotypic_count"])
            expr = np.array(df_tf.iloc[:,expr_start_iloc:expr_end_iloc])

            r_all_tissue = np.array([])
            p_all_tissue = np.array([])
            for tissue in range(len(tissues)):
                tissue_expr = expr[:,tissue]

                r, p = pearsonr(tfbs_counts, tissue_expr)
                r_all_tissue = np.append(r_all_tissue, r)
                p_all_tissue = np.append(p_all_tissue, p)
            # Appand r and p for single tfs into one big 2d array
            r_all_tf = np.vstack((r_all_tf, r_all_tissue))
            p_all_tf = np.vstack((p_all_tf, p_all_tissue))

        else:
            print(f"{tf} has only 1 entry. No Correlation could be calculated")
        # Add columns to DataFrame and set index to tf names
        r_df = pd.DataFrame(r_all_tf, columns=tissues)
        r_df.index = tfs_lst
        p_df = pd.DataFrame(p_all_tf, columns=tissues)
        p_df.index = tfs_lst       
        
    return r_df, p_df

# %%
r_df, p_df = get_pearson_all_tissues(df_new, expr_start_iloc=10)

# %%
## Which TFBS have only one TFBS per Promotor?
# r_df[np.all(r_df.isna(), axis=1)].index.to_numpy()

# # Sort both DataFrames based on the sum of the correlation coefficient and remove NANs.
# r_df_s = r_df.reindex(abs(r_df.sum(axis=1)).sort_values(ascending=False).index).dropna()
# p_df_s = p_df.reindex(abs(r_df.sum(axis=1)).sort_values(ascending=False).index).dropna()


# r_df_filtered_by_p_value = r_df_s[p_df_s<0.05]


# r_df_filtered_by_p_value_remove_nan_rows = r_df_filtered_by_p_value[~np.all(r_df_filtered_by_p_value.isna(), axis=1)]
# r_df_filtered_by_p_value_remove_nan_rows_sort_by_mean = r_df_filtered_by_p_value_remove_nan_rows.reindex(abs(r_df_filtered_by_p_value_remove_nan_rows.mean(axis=1, skipna=True)).sort_values(ascending=False).index)
# Out:
# 56

# %%
value_max = max(max(abs(r_df_filtered_by_p_value.max())), max(abs(r_df_filtered_by_p_value.min())))
value_min = -value_max


fig, ax = plt.subplots(figsize=(10, 35))
heatmap = sns.heatmap(r_df_filtered_by_p_value_remove_nan_rows_sort_by_mean, cmap='coolwarm', fmt=".2f", linewidths=0.01,vmin=value_min, vmax=value_max, cbar_kws={"orientation": "horizontal", "location":"top", "label":"Pearson coefficient", "pad":0.09})
#plt.title('Genexpression in different tissues')
plt.xlabel('TFBS')
plt.ylabel('Tissues')

ax.xaxis.tick_top()
ax.set_xlabel("")
ax.xaxis.set_label_position("top")
plt.xticks(rotation=90)


plt.tight_layout()
#fig.savefig("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/Heatmap/Pearson_filtered_remove_p_sort_by_mean_withoutNAN.png")
plt.show()
