# %%
#import pybedtools

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
#import seaborn.objects as so

from scipy.stats import pearsonr, spearmanr
import glob

# %%
path_heatmap = r"CSV_log2_mean_GenExr_diffrent_tissue_all_TFBS_ROBUST_extend_with_traget_gene_count.csv"
path_id_count = r"CSV_tf_id_count.csv"

# %%
df = pd.read_csv(path_heatmap).set_index("tf")
id_count = pd.read_csv(path_id_count).set_index("tf")["geneID"]
df.min()
# Out:
# Adipose - Subcutaneous                       0.646029
# Adipose - Visceral (Omentum)                 0.538022
# Adrenal Gland                               -0.201830
# Artery - Aorta                               0.645540
# Artery - Coronary                            0.823539
# Artery - Tibial                              0.585882
# Bladder                                      0.948806
# Brain - Amygdala                            -0.750104
# Brain - Anterior cingulate cortex (BA24)    -0.336283
# Brain - Caudate (basal ganglia)             -0.212223
# Brain - Cerebellar Hemisphere               -0.418947
# Brain - Cerebellum                          -0.123609
# Brain - Cortex                              -0.008181
# Brain - Frontal Cortex (BA9)                -0.019892
# Brain - Hippocampus                         -0.701227
# Brain - Hypothalamus                        -0.202734
# Brain - Nucleus accumbens (basal ganglia)   -0.061760
# Brain - Putamen (basal ganglia)             -0.559373
# Brain - Spinal cord (cervical c-1)          -0.710668
# Brain - Substantia nigra                    -0.622754
# Breast - Mammary Tissue                      0.971306
# Cells - Cultured fibroblasts                -1.036617
# Cells - EBV-transformed lymphocytes         -0.261863
# Cervix - Ectocervix                          0.809600
# Cervix - Endocervix                          1.052152
# Colon - Sigmoid                              0.443494
# Colon - Transverse                           0.602178
# Esophagus - Gastroesophageal Junction        0.434196
# Esophagus - Mucosa                           0.323907
# Esophagus - Muscularis                       0.367640
# Fallopian Tube                               1.288352
# Heart - Atrial Appendage                    -0.342635
# Heart - Left Ventricle                      -0.944494
# Kidney - Cortex                             -0.807044
# Kidney - Medulla                            -0.736390
# Liver                                        0.423433
# Lung                                         0.656354
# Minor Salivary Gland                         0.461647
# Muscle - Skeletal                           -0.267739
# Nerve - Tibial                               0.913292
# Ovary                                        0.829076
# Pancreas                                    -0.834030
# Pituitary                                    0.834497
# Prostate                                     0.726615
# Skin - Not Sun Exposed (Suprapubic)          0.704923
# Skin - Sun Exposed (Lower leg)               0.868614
# Small Intestine - Terminal Ileum             0.741732
# Spleen                                       0.000691
# Stomach                                      0.143591
# Testis                                       1.385610
# Thyroid                                      1.208089
# Uterus                                       0.839961
# Vagina                                       1.049809
# Whole Blood                                 -2.539798
# dtype: float64

# %% [markdown]
# ## Reduce DataFrame

# %%
tf_most_target_genes = ['MYC', 'ESR1', 'SP1', 'CTCF', 'E2F1', 'MAX', 'RUNX1', 'TFAP2C', 'AR', 'KLF5', 'JUN', 'RELA', 'MYCN', 'CREB1', 'E2F6', 'SP2']

tf_smallest_expr = ["NR1H4", "SOX10", "HNF1B", "HNF1A", "ISL1"]
tf_biggest_expr = ["NR5A1", "XBP1", "TFEB", "HSF2", "NR2C1"]

# %%
df_plot = df.loc[tf_most_target_genes]
id_count_plot = id_count.loc[tf_most_target_genes]

# %%
df_plot = df.loc[tf_biggest_expr+tf_smallest_expr]
id_count_plot = id_count.loc[tf_biggest_expr+tf_smallest_expr]

# %% [markdown]
# ## Plots

# %%
value_max = 1.6
value_min = 4.1

my_cmap = plt.get_cmap("viridis").copy()
my_cmap.set_over("#FFFF99")
my_cmap.set_under("#000033")

fig, ax = plt.subplots(figsize=(13, 8))
heatmap = sns.heatmap(df_plot, fmt=".2f", linewidths=0.01, robust=True, cmap=my_cmap, cbar_kws={"orientation": "horizontal", "location":"bottom", "label":"log2(GeneExpr)", "extend":"both"}, vmin=value_min, vmax=value_max)
#plt.title('Genexpression in different tissues')
plt.xlabel('Tissues')
plt.ylabel('TFBS')

ax.xaxis.tick_top()
ax.set_xlabel("")
ax.xaxis.set_label_position("top")
plt.xticks(rotation=90)

ax2 = ax.twinx()
ax2.set_ylabel("Count of Target-Genes")
ax2.set_ylim([0,ax.get_ylim()[0]])
ax2.set_yticks(ax.get_yticks())
ax2.set_yticklabels(id_count_plot.values[::-1])

plt.tight_layout()
# fig.savefig("heatmap_most_target_genes.png")
plt.show()

# %%
# Ist nicht wirklich normalized!! um zu normalizen muss ich min und max beachten!

# Normalize the expression values for each tissue. So that we can compare for each TF the Tissues
df_norm_tissue = df/df.max()

# Normalize the expression values for each TF
df_norm_tf = df.div(df.max(axis=1), axis=0)

# df_norm = df_norm_tissue.div(df_norm_tissue.max(axis=1), axis=0)

# %%
value_max = max(df.max())
value_min = min(df.min())

my_cmap = plt.get_cmap("viridis").copy()
my_cmap.set_over("#FFFF99")
my_cmap.set_under("#000033")

fig, ax = plt.subplots(figsize=(10, 62))
heatmap = sns.heatmap(df_norm_tf,cmap=my_cmap, fmt=".2f", linewidths=0.01, cbar_kws={"orientation": "horizontal", "location":"top", "label":"log2(GeneExpr)", "extend":"both"}, robust=True)
#plt.title('Genexpression in different tissues')
plt.xlabel('Tissues')
plt.ylabel('TFBS')

ax.xaxis.tick_top()
ax.set_xlabel("")
ax.xaxis.set_label_position("top")
plt.xticks(rotation=90)

ax2 = ax.twinx()
ax2.set_ylabel("Count of Target-Genes")
ax2.set_ylim([0,ax.get_ylim()[0]])
ax2.set_yticks(ax.get_yticks())
ax2.set_yticklabels(id_count.values[::-1])

plt.tight_layout()
#fig.savefig("/sybig/projects/GeneRegulation/data/jme/Bachelorarbeit/data/Single_TFBS/Heatmap/log2_mean_GenExr_diffrent_tissue_all_TFBS_ROBUST_extend.png")
# fig.savefig("images/log2_mean_GenExr_diffrent_tissue_all_TFBS_ROBUST_extend_with_traget_gene_count.png")
plt.show()
